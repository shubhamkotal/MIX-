# %%
from google.colab import drive
drive.mount('/content/gdrive')  #mounting
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive'  
# set working directory
# Out:
# /content/gdrive/My Drive

# %%
# !pip install soundfile pesq pystoi  # required installations
# Out:
# Collecting soundfile
#   Downloading https://files.pythonhosted.org/packages/eb/f2/3cbbbf3b96fb9fa91582c438b574cff3f45b29c772f94c400e2c99ef5db9/SoundFile-0.10.3.post1-py2.py3-none-any.whl
# Collecting pesq
#   Downloading https://files.pythonhosted.org/packages/98/79/1da494ca32ad9e57a76202f756b3b67e8a404904c7004d290c0063a845c2/pesq-0.0.2.tar.gz
# Collecting pystoi
#   Downloading https://files.pythonhosted.org/packages/4c/d8/58a5deefb57e3ca78d6421d2ec536880a29ac0e497b2d1baded6f2153beb/pystoi-0.3.3.tar.gz
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.6/dist-packages (from soundfile) (1.14.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pystoi) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from pystoi) (1.4.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0->soundfile) (2.20)
# Building wheels for collected packages: pesq, pystoi
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.2-cp36-cp36m-linux_x86_64.whl size=159949 sha256=e94d59a05401853aaf245ecc60cb3d916285e0becfc9e884eed98c51a7f46b40
#   Stored in directory: /root/.cache/pip/wheels/95/96/02/64c5b0ffb69c5651438f511679983a6ed3ef23873d2e9ecde4
#   Building wheel for pystoi (setup.py) ... done
#   Created wheel for pystoi: filename=pystoi-0.3.3-py2.py3-none-any.whl size=7781 sha256=84d43b3977c3e5ed73265855ff60d482de8fa4993c1496c65db324bffa6abd80
#   Stored in directory: /root/.cache/pip/wheels/6b/6c/b2/d49af4b7ee4ce275cf2511484b043e09b9cb7ae90c1accb17a
# Successfully built pesq pystoi
# Installing collected packages: soundfile, pesq, pystoi
# Successfully installed pesq-0.0.2 pystoi-0.3.3 soundfile-0.10.3.post1

# %%
# %cd '/content/gdrive/MyDrive/DEEP/DeepXi/'
# Out:
# /content/gdrive/MyDrive/DEEP/DeepXi

# %%
# !ls
# Out:
# 1-s2.0-S0167639318304308-main.pdf  fig_front-end.png	     README.md
# data				   fig_training_example.png  requirements.txt
# DeepMMSE.pdf			   fig_xi_dist.png	     run_demand_vb.sh
# deepxi				   LICENSE.txt		     run.m
# DeepXi_New_DSP.ipynb		   log			     run.sh
# eval_example.m			   main.py		     seq_mask_batch.mat
# eval_stats.m			   model		     set
# fig_Deep-Xi-ResNet.png		   out

# %%
#import platform; platform.node()

# %%
#!ls

# %%
import soundfile as sf
import os 
# !pip install pydub

#files=os.listdir("set/train_clean_speech")
#'p274_120.wav' in files
# x=sf.read("set/train_clean_speech/p274_120.wav")
# Out:
# Collecting pydub
#   Downloading https://files.pythonhosted.org/packages/7b/d1/fbfa79371a8cd9bb15c2e3c480d7e6e340ed5cc55005174e16f48418333a/pydub-0.24.1-py2.py3-none-any.whl
# Installing collected packages: pydub
# Successfully installed pydub-0.24.1

# %%
#!bash run.sh VER="resnet-1.0n" TRAIN=1 GAIN="wf"

# %%
#REQUIRED LIBRARIES

# Preprocessing and operations on Audio
import soundfile as sf 
from scipy.io.wavfile import read

# Math operations and 
import math
import functools
import scipy.special as spsp
from scipy.special import exp1

# File handling 
import glob, os

# Data handling 
import numpy as np
from tqdm import tqdm
#from pydub import AudioSegment
# Deep learning: Modelling helpers
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.models import Model
from tensorflow.python.ops.signal import window_ops
from tensorflow.keras.layers import Activation, Add, Conv1D, Conv2D, Dense, Dropout,Flatten, LayerNormalization, MaxPooling2D, ReLU, Input, Masking

# %%
# from pydub import AudioSegment
# sound = AudioSegment.from_wav("/content/gdrive/MyDrive/DEEP/DeepXi/set/test_noisy_speech/2.wav")
# sound = sound.set_channels(1)
# sound.export("/content/gdrive/MyDrive/DEEP/DeepXi/set/test_noisy_speech/2.wav", format="wav")

# %%
#hemasunder
# Functions for audio handling
def save_wav(path, wav, f_s):
    """"
    save_wav: Save the denoised audio to the given path
        path                  - path to save the output audio file 
        f_s                   - sampling freq
        wav                   - audio file extension
        np.squeeze            - Remove single-dimensional entries from the shape of an array
        if block(isinstance)  - function returns True if the specified object is of the specified type, otherwise False 
                                checking if the file is float dtype
        np.asarray            - convert an given input to an array
     """
    wav = np.squeeze(wav)
    if isinstance(wav[0], np.float32):
        wav = np.asarray(np.multiply(wav, 32768.0), dtype=np.int16) 
    sf.write(path, wav, f_s)

def read_wav(path):
    """
    read_wav: Read the audio files from a given path
    """
    wav, f_s = sf.read(path, dtype='int16')
    return wav, f_s

def batch(fdir):
    """
    batch: Create a bacth of input audio files
        fdir           - Input path of audio files 
        fname_l        - list of file names.
        wav_l          - list of fetched_audio files
        len_l          - list of audio file lengths
    Returns: 
    audio_files_numpy_format, np array of audio file legnths, list of file_names
    """
    fname_l = [] 
    wav_l = [] 
    fnames = ['*.wav', '*.flac', '*.mp3']

    #get all the supported sound file types from the given path
    for fname in fnames:  
        for fpath in glob.glob(os.path.join(fdir, fname)): 
            (wav, _) = read_wav(fpath) # read each audio file using the soundfile library 
            if np.isnan(wav).any() or np.isinf(wav).any():
                raise ValueError('Error: NaN or Inf value. File path: %s.' % (fdir))
            wav_l.append(wav) #add the wavefile name to the wav_l list
            fname_l.append(os.path.basename(os.path.splitext(fpath)[0])) # append respective path 

    len_l = []
    # get maximum audio length among all the files, so that all the other files are padded with zeroes to have a uniform batch
    maxlen = max(len(wav) for wav in wav_l) 
    wav_np = np.zeros([len(wav_l), maxlen], np.int16) # creating a numpy array of zeroes, with the length of the largest audio file as a dimension 

    for (i, wav) in zip(range(len(wav_l)), wav_l):
      #Overlapping the zeros in the numpy array of zeroes, to create a padded array for the smaller files to make them equal in size to large files
        wav_np[i,:len(wav)] = wav 
        len_l.append(len(wav))
    return wav_np, np.array(len_l, np.int32),fname_l

# %%
#CUSTOM CLASS FOR DIGITAL SIGNAL PROCESSING 
var = 0
varout = 0

class STFT:
    """
    Short-Term Fourier Transform:
        N_d                -  window duration (samples)
        N_s                -  window shift (samples)
        NFFT               -  number of DFT componts [ Discrete fourier transform]
        f_s                - sampling freq
    """
    #Mohit
    def __init__(self, N_d, N_s, NFFT, f_s):
        self.N_d = N_d
        self.N_s = N_s
        self.NFFT = NFFT
        self.f_s = f_s
        self.W = functools.partial(window_ops.hamming_window, periodic=False) # A callable that takes a window length and returns a [window_length] Tensor of samples in the provided datatype.
        self.ten = tf.cast(10.0, tf.float32) # Casting the tensor to the float32 type
    #Mohit
    def polar_analysis(self, x):
        """
        x                  -  Input numpy array
        tf.signal.stft     -  Computes the Short-time Fourier Transform of signals
        Returns:
        tf.abs             -  computes absolute value of tensor         
        tf.math.angle      -  returns element wise arguments of a complex tensor
      """
        STFT = tf.signal.stft(x, self.N_d, self.N_s, self.NFFT, window_fn=self.W, pad_end=True) # Find STFT of a given signal
        return tf.abs(STFT), tf.math.angle(STFT) # Returns magnitude and phase angle of resulting STFT
    #Rohan
    def polar_synthesis(self, STMS, STPS):
        """
        tf.cast                      - Casts a tensor to a new type
        tf.complex                   - A Tensor of type complex64 or complex128
        tf.exp                       - performs exponential operation on a tensor
        
        Returns:
        tf.signal.inverse_stft       - inverse the stft input signals
        STMS                         - short time magnitude spectrum
        STPS                         - short time phase spectrum
        """
        STFT = tf.cast(STMS, tf.complex64)*tf.exp(1j*tf.cast(STPS, tf.complex64)) 
        return tf.signal.inverse_stft(STFT, self.N_d, self.N_s, self.NFFT, tf.signal.inverse_stft_window_fn(self.N_s, self.W))

class DeepXiInput(STFT):
    def __init__(self, N_d, N_s, NFFT, f_s, mu=None, sigma=None):
        """
        defining mu and sigma
        """
        super().__init__(N_d, N_s, NFFT, f_s)
        self.mu = mu 
        self.sigma = sigma
    #Nobody        
    def observation(self, x):
        """
        Returns STMS and STPS from the given input numpy (converted audio file)
        """
        x = self.normalise(x)
        x_STMS, x_STPS = self.polar_analysis(x)
        return x_STMS, x_STPS
    


    # Defining all functions required for processing audio file after converting it to tensors using tensor mathematical operations. 
    #Shubham
    def normalise(self, x):
        #normailzation / standardization
        """
        Normalize the given input np array  
        """
        return tf.truediv(tf.cast(x, tf.float32), 32768.0) # Divides x tensor by y elementwise
    #Shubham
    def n_frames(self, N):
        """
        tf.math.ceil - Return the ceiling of the input, element-wise
        """
        return tf.cast(tf.math.ceil(tf.truediv(tf.cast(N, tf.float32), tf.cast(self.N_s, tf.float32))), tf.int32)


    #Surya
    def xi_hat(self, xi_bar_hat):
        """
        scipy.special.erfinv(y)  -  Inverse of the gause error function erf.
        """ 
        xi_db_hat = np.add(np.multiply(np.multiply(self.sigma, np.sqrt(2.0)),
                                       spsp.erfinv(np.subtract(np.multiply(2.0, xi_bar_hat), 1))), self.mu)
        return np.power(10.0, np.divide(xi_db_hat, 10.0))

# %%
# MMSE-LSA gain function.
#Purnasai
def gfunc(xi, gamma=None):
    """
    MMSE-LSA Gain function
    """
    nu = np.multiply(np.divide(xi, np.add(1, xi)), gamma)
    G = np.multiply(np.divide(xi, np.add(1, xi)), np.exp(np.multiply(0.5, exp1(nu))))
    return G

# %%
# Modelling ResNet architecture

class ResNet:
    """
    ResNet: Residual Neural Network - Base model for DeepXi architeture
    """
    def __init__(self,inp,n_outp,n_blocks,d_model,d_f,k,max_d_rate,padding,):
        self.d_model = d_model
        self.d_f = d_f
        self.k = k
        self.n_outp = n_outp
        self.padding = padding
        self.first_layer = self.feedforward(inp)
        self.layer_list = [self.first_layer]
        for i in range(n_blocks): self.layer_list.append(self.block(self.layer_list[-1], int(2**(i%(np.log2(max_d_rate)+1)))))
        self.logits = Conv1D(self.n_outp, 1, dilation_rate=1, use_bias=True)(self.layer_list[-1])
        self.outp = Activation('sigmoid')(self.logits)     

    # 1st layer
    def feedforward(self, inp):
        """
        1D convolution layer (temporal convolution)   -    This layer creates a convolution kernel that is convolved with the layer input over a single spatial (or temporal) 
                                                            dimension to produce a tensor of outputs.

        """
        print('so=====',self.d_model)
        ff = Conv1D(self.d_model, 1, dilation_rate=1, use_bias=False)(inp)
        norm = LayerNormalization(axis=2, epsilon=1e-6)(ff)
        act = ReLU()(norm)
        return act

    # 2nd layer
    def block(self, inp, d_rate):
        """
        2D convolution layer (spatial convolution)
        """
        self.conv_1 = self.unit(inp, self.d_f, 1, 1, False)
        self.conv_2 = self.unit(self.conv_1, self.d_f, self.k, d_rate,
            False)
        self.conv_3 = self.unit(self.conv_2, self.d_model, 1, 1, True)
        residual = Add()([inp, self.conv_3])
        return residual

    # 3rd layer
    def unit(self, inp, n_filt, k, d_rate, use_bias):
        """
        dilation_rate                     : an integer or tuple/list of 2 integers, specifying the dilation rate to use for dilated convolution.
                                          Can be a single integer to specify the same value for all spatial dimensions. 
        use_bias                          : Boolean, whether the layer uses a bias vector.
        Relu                              : Clips value in range of 0 to infinity , so clips all negative value to zero
        normalization layer               :  Normalize the activations of the previous layer for each given example in a batch independently,
                                           rather than across a batch like Batch Normalization. i.e. applies a transformation that maintains the mean activation within each example close to 0
                                             and the activation standard deviation close to 1.
        """
        norm = LayerNormalization(axis=2, epsilon=1e-6)(inp)
        act = ReLU()(norm)
        conv = Conv1D(n_filt, k, padding=self.padding, dilation_rate=d_rate,
            use_bias=use_bias)(act)
        return conv

# %%
class DeepXi(DeepXiInput):
    def __init__(self,N_d,N_s,NFFT,f_s,model_path,stat_path,**kwargs):  
        super().__init__(N_d, N_s, NFFT, f_s)
        self.n_feat = math.ceil(self.NFFT/2 + 1)
        self.n_outp = self.n_feat
        self.inp = Input(name='inp', shape=[None, self.n_feat], dtype='float32')
        self.mask = Masking(mask_value=0.0)(self.inp) 
        #Masking is a way to tell sequence-processing layers that certain timesteps in an input are missing, and thus should be skipped when processing the data.
        
        self.network = ResNet(
            inp=self.mask,
            n_outp=self.n_outp,
            n_blocks=kwargs['n_blocks'],
            d_model=kwargs['d_model'],
            d_f=kwargs['d_f'],
            k=kwargs['k'],
            max_d_rate=kwargs['max_d_rate'],
            padding=kwargs['padding'],
            )
        #Padding is done in order to make all sequences in a batch fit a given standard length.
        self.model = Model(inputs=self.inp, outputs=self.network.outp)
        self.model.summary()
        # The Actual program starts from this line
        self.sample_stats(stat_path) # Load sample statistics file to derive mu and sigma values
        self.model.load_weights(model_path) #Load Weights of Saved_model from model_path


    def infer(self,test_x,test_x_len,test_x_base_names,out_path='out/denoised/',n_filters=40,):
        
        out_path = out_path # setting output directory 
        
        print("Processing observations...")
        x_STMS_batch, x_STPS_batch, n_frames = self.observation_batch(test_x, test_x_len) # observation_batch is function defined at the last part of the cell

        print("Performing inference...")
        xi_bar_hat_batch = self.model.predict(x_STMS_batch, batch_size=1, verbose=1)# MAX TIME TAKEN
        #purnasai
        batch_size = len(test_x_len)  # taking length of x_batch
        for i in tqdm(range(batch_size)):  # Module for iterating batches # here batch size is 1 so it will iterate only one time.
            base_name = test_x_base_names[i]  #this and below are all the mathematical operations done for audio processing and getting dezire output as per domain understanding.
            x_STMS = x_STMS_batch[i,:n_frames[i],:] 
            x_STPS = x_STPS_batch[i,:n_frames[i],:]
            xi_bar_hat = xi_bar_hat_batch[i,:n_frames[i],:]
            xi_hat = self.xi_hat(xi_bar_hat)
            
            y_STMS = np.multiply(x_STMS, gfunc(xi_hat, xi_hat+1))
            y = self.polar_synthesis(y_STMS, x_STPS).numpy()
            save_wav(out_path+ base_name + '.wav', y, self.f_s)
    #purnasai
    def sample_stats(self,stats_path='data/'): # loading sample stats present in sample stats folder as a zip file # existing stats files, required for following operations.
        if os.path.exists(stats_path + 'stats.npz'):
            print('Loading sample statistics...')
            with np.load(stats_path + 'stats.npz') as stats:
                self.mu = stats['mu_hat']   # getting value for mu from the stats file
                self.sigma = stats['sigma_hat'] #getting value for sigma from the stats file
                

    #Rohan
    def observation_batch(self, x_batch, x_batch_len):
        """
        batch_size       - getting size of numpy (converted audio)
        max_n_frames     - taking maximum value of array size
        x_STMS_batch     - create numpy of zeros to have equal sized arrays across the batch
        n_feat           - 
        STMS             - short time magnitude spectrum
        STPS             - short time phase spectrum
        """
        batch_size = len(x_batch) # taking length of x_batch
        max_n_frames = self.n_frames(max(x_batch_len)) # getting nframe value for input x_batch_len
        x_STMS_batch = np.zeros([batch_size, max_n_frames, self.n_feat], np.float32) # creating a numpy with zero values but of desire shape as per dimension of batch size,max_n_frames
        x_STPS_batch = np.zeros([batch_size, max_n_frames, self.n_feat], np.float32) # creating a numpy with zero values but of desire shape as per dimension of batch size,max_n_frames
        n_frames_batch = [self.n_frames(i) for i in x_batch_len]  # getting nframe value for value in x_batch_len
        for i in tqdm(range(batch_size)): # Module for iterating batches # here batch size is 1 so it will iterate only one time.
            x_STMS, x_STPS = self.observation(x_batch[i,:x_batch_len[i]])  # this and below are the mathematical operations done for audio processing and getting dezire output as per domain understanding.
            x_STMS_batch[i,:n_frames_batch[i],:] = x_STMS.numpy() 
            x_STPS_batch[i,:n_frames_batch[i],:] = x_STPS.numpy()
        return x_STMS_batch, x_STPS_batch, n_frames_batch

# %%
#VARIABLES FOR THE MODEL
d_model  = 256     #block output size
n_blocks  = 40     #no of blocks in the model
d_f = 64           #block bottlekneck size
k =  3             #convolution kernel size
max_d_rate = 16    #max_dilation_rate
padding = "causal" #type of convnet padding
f_s  = 16000       #sampling frequency
T_d  = 32          #window duration
T_s  =  16         #window shift
#rohan
N_d = int(f_s*T_d*0.001) # window duration (samples).
N_s = int(f_s*T_s*0.001) # window shift (samples).
NFFT = int(pow(2, np.ceil(np.log2(N_d)))) # number of DFT components.


# PATH VARIABLE
data_path='data/' # Path of the sample_stats file that to be loaded for inference purpose.
test_x_path='set/test_noisy_speech' # Path of the inputs : noisy audio files
out_path='out/denoised/' # Path to which out the output audio file is saved.
model_path='/content/gdrive/MyDrive/DEEP/DeepXi/model/resnet-1.0c/epoch-179/variables/variables' # Path of the TF Saved_model


test_x, test_x_len, test_x_base_names = batch(test_x_path) # Fetch the test noisy audio inputs along with its names.

# DeepXi object instantiation
deepxi = DeepXi(N_d=N_d,N_s=N_s,NFFT=NFFT,f_s=f_s,d_model=d_model,n_blocks=n_blocks,d_f=d_f,k=k,max_d_rate =max_d_rate,padding=padding
                ,model_path=model_path,stat_path=data_path)
# Out:
# so===== 256
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inp (InputLayer)                [(None, None, 257)]  0
# __________________________________________________________________________________________________
# masking_1 (Masking)             (None, None, 257)    0           inp[0][0]
# __________________________________________________________________________________________________
# conv1d_122 (Conv1D)             (None, None, 256)    65792       masking_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_121 (LayerN (None, None, 256)    512         conv1d_122[0][0]
# __________________________________________________________________________________________________
# re_lu_121 (ReLU)                (None, None, 256)    0           layer_normalization_121[0][0]
# __________________________________________________________________________________________________
# layer_normalization_122 (LayerN (None, None, 256)    512         re_lu_121[0][0]
# __________________________________________________________________________________________________
# re_lu_122 (ReLU)                (None, None, 256)    0           layer_normalization_122[0][0]
# __________________________________________________________________________________________________
# conv1d_123 (Conv1D)             (None, None, 64)     16384       re_lu_122[0][0]
# __________________________________________________________________________________________________
# layer_normalization_123 (LayerN (None, None, 64)     128         conv1d_123[0][0]
# __________________________________________________________________________________________________
# re_lu_123 (ReLU)                (None, None, 64)     0           layer_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv1d_124 (Conv1D)             (None, None, 64)     12288       re_lu_123[0][0]
# __________________________________________________________________________________________________
# layer_normalization_124 (LayerN (None, None, 64)     128         conv1d_124[0][0]
# __________________________________________________________________________________________________
# re_lu_124 (ReLU)                (None, None, 64)     0           layer_normalization_124[0][0]
# __________________________________________________________________________________________________
# conv1d_125 (Conv1D)             (None, None, 256)    16640       re_lu_124[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, None, 256)    0           re_lu_121[0][0]
#                                                                  conv1d_125[0][0]
# __________________________________________________________________________________________________
# layer_normalization_125 (LayerN (None, None, 256)    512         add_40[0][0]
# __________________________________________________________________________________________________
# re_lu_125 (ReLU)                (None, None, 256)    0           layer_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv1d_126 (Conv1D)             (None, None, 64)     16384       re_lu_125[0][0]
# __________________________________________________________________________________________________
# layer_normalization_126 (LayerN (None, None, 64)     128         conv1d_126[0][0]
# __________________________________________________________________________________________________
# re_lu_126 (ReLU)                (None, None, 64)     0           layer_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv1d_127 (Conv1D)             (None, None, 64)     12288       re_lu_126[0][0]
# __________________________________________________________________________________________________
# layer_normalization_127 (LayerN (None, None, 64)     128         conv1d_127[0][0]
# __________________________________________________________________________________________________
# re_lu_127 (ReLU)                (None, None, 64)     0           layer_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv1d_128 (Conv1D)             (None, None, 256)    16640       re_lu_127[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, None, 256)    0           add_40[0][0]
#                                                                  conv1d_128[0][0]
# __________________________________________________________________________________________________
# layer_normalization_128 (LayerN (None, None, 256)    512         add_41[0][0]
# __________________________________________________________________________________________________
# re_lu_128 (ReLU)                (None, None, 256)    0           layer_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv1d_129 (Conv1D)             (None, None, 64)     16384       re_lu_128[0][0]
# __________________________________________________________________________________________________
# layer_normalization_129 (LayerN (None, None, 64)     128         conv1d_129[0][0]
# __________________________________________________________________________________________________
# re_lu_129 (ReLU)                (None, None, 64)     0           layer_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv1d_130 (Conv1D)             (None, None, 64)     12288       re_lu_129[0][0]
# __________________________________________________________________________________________________
# layer_normalization_130 (LayerN (None, None, 64)     128         conv1d_130[0][0]
# __________________________________________________________________________________________________
# re_lu_130 (ReLU)                (None, None, 64)     0           layer_normalization_130[0][0]
# __________________________________________________________________________________________________
# conv1d_131 (Conv1D)             (None, None, 256)    16640       re_lu_130[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, None, 256)    0           add_41[0][0]
#                                                                  conv1d_131[0][0]
# __________________________________________________________________________________________________
# layer_normalization_131 (LayerN (None, None, 256)    512         add_42[0][0]
# __________________________________________________________________________________________________
# re_lu_131 (ReLU)                (None, None, 256)    0           layer_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv1d_132 (Conv1D)             (None, None, 64)     16384       re_lu_131[0][0]
# __________________________________________________________________________________________________
# layer_normalization_132 (LayerN (None, None, 64)     128         conv1d_132[0][0]
# __________________________________________________________________________________________________
# re_lu_132 (ReLU)                (None, None, 64)     0           layer_normalization_132[0][0]
# __________________________________________________________________________________________________
# conv1d_133 (Conv1D)             (None, None, 64)     12288       re_lu_132[0][0]
# __________________________________________________________________________________________________
# layer_normalization_133 (LayerN (None, None, 64)     128         conv1d_133[0][0]
# __________________________________________________________________________________________________
# re_lu_133 (ReLU)                (None, None, 64)     0           layer_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv1d_134 (Conv1D)             (None, None, 256)    16640       re_lu_133[0][0]
# __________________________________________________________________________________________________
# add_43 (Add)                    (None, None, 256)    0           add_42[0][0]
#                                                                  conv1d_134[0][0]
# __________________________________________________________________________________________________
# layer_normalization_134 (LayerN (None, None, 256)    512         add_43[0][0]
# __________________________________________________________________________________________________
# re_lu_134 (ReLU)                (None, None, 256)    0           layer_normalization_134[0][0]
# __________________________________________________________________________________________________
# conv1d_135 (Conv1D)             (None, None, 64)     16384       re_lu_134[0][0]
# __________________________________________________________________________________________________
# layer_normalization_135 (LayerN (None, None, 64)     128         conv1d_135[0][0]
# __________________________________________________________________________________________________
# re_lu_135 (ReLU)                (None, None, 64)     0           layer_normalization_135[0][0]
# __________________________________________________________________________________________________
# conv1d_136 (Conv1D)             (None, None, 64)     12288       re_lu_135[0][0]
# __________________________________________________________________________________________________
# layer_normalization_136 (LayerN (None, None, 64)     128         conv1d_136[0][0]
# __________________________________________________________________________________________________
# re_lu_136 (ReLU)                (None, None, 64)     0           layer_normalization_136[0][0]
# __________________________________________________________________________________________________
# conv1d_137 (Conv1D)             (None, None, 256)    16640       re_lu_136[0][0]
# __________________________________________________________________________________________________
# add_44 (Add)                    (None, None, 256)    0           add_43[0][0]
#                                                                  conv1d_137[0][0]
# __________________________________________________________________________________________________
# layer_normalization_137 (LayerN (None, None, 256)    512         add_44[0][0]
# __________________________________________________________________________________________________
# re_lu_137 (ReLU)                (None, None, 256)    0           layer_normalization_137[0][0]
# __________________________________________________________________________________________________
# conv1d_138 (Conv1D)             (None, None, 64)     16384       re_lu_137[0][0]
# __________________________________________________________________________________________________
# layer_normalization_138 (LayerN (None, None, 64)     128         conv1d_138[0][0]
# __________________________________________________________________________________________________
# re_lu_138 (ReLU)                (None, None, 64)     0           layer_normalization_138[0][0]
# __________________________________________________________________________________________________
# conv1d_139 (Conv1D)             (None, None, 64)     12288       re_lu_138[0][0]
# __________________________________________________________________________________________________
# layer_normalization_139 (LayerN (None, None, 64)     128         conv1d_139[0][0]
# __________________________________________________________________________________________________
# re_lu_139 (ReLU)                (None, None, 64)     0           layer_normalization_139[0][0]
# __________________________________________________________________________________________________
# conv1d_140 (Conv1D)             (None, None, 256)    16640       re_lu_139[0][0]
# __________________________________________________________________________________________________
# add_45 (Add)                    (None, None, 256)    0           add_44[0][0]
#                                                                  conv1d_140[0][0]
# __________________________________________________________________________________________________
# layer_normalization_140 (LayerN (None, None, 256)    512         add_45[0][0]
# __________________________________________________________________________________________________
# re_lu_140 (ReLU)                (None, None, 256)    0           layer_normalization_140[0][0]
# __________________________________________________________________________________________________
# conv1d_141 (Conv1D)             (None, None, 64)     16384       re_lu_140[0][0]
# __________________________________________________________________________________________________
# layer_normalization_141 (LayerN (None, None, 64)     128         conv1d_141[0][0]
# __________________________________________________________________________________________________
# re_lu_141 (ReLU)                (None, None, 64)     0           layer_normalization_141[0][0]
# __________________________________________________________________________________________________
# conv1d_142 (Conv1D)             (None, None, 64)     12288       re_lu_141[0][0]
# __________________________________________________________________________________________________
# layer_normalization_142 (LayerN (None, None, 64)     128         conv1d_142[0][0]
# __________________________________________________________________________________________________
# re_lu_142 (ReLU)                (None, None, 64)     0           layer_normalization_142[0][0]
# __________________________________________________________________________________________________
# conv1d_143 (Conv1D)             (None, None, 256)    16640       re_lu_142[0][0]
# __________________________________________________________________________________________________
# add_46 (Add)                    (None, None, 256)    0           add_45[0][0]
#                                                                  conv1d_143[0][0]
# __________________________________________________________________________________________________
# layer_normalization_143 (LayerN (None, None, 256)    512         add_46[0][0]
# __________________________________________________________________________________________________
# re_lu_143 (ReLU)                (None, None, 256)    0           layer_normalization_143[0][0]
# __________________________________________________________________________________________________
# conv1d_144 (Conv1D)             (None, None, 64)     16384       re_lu_143[0][0]
# __________________________________________________________________________________________________
# layer_normalization_144 (LayerN (None, None, 64)     128         conv1d_144[0][0]
# __________________________________________________________________________________________________
# re_lu_144 (ReLU)                (None, None, 64)     0           layer_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv1d_145 (Conv1D)             (None, None, 64)     12288       re_lu_144[0][0]
# __________________________________________________________________________________________________
# layer_normalization_145 (LayerN (None, None, 64)     128         conv1d_145[0][0]
# __________________________________________________________________________________________________
# re_lu_145 (ReLU)                (None, None, 64)     0           layer_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv1d_146 (Conv1D)             (None, None, 256)    16640       re_lu_145[0][0]
# __________________________________________________________________________________________________
# add_47 (Add)                    (None, None, 256)    0           add_46[0][0]
#                                                                  conv1d_146[0][0]
# __________________________________________________________________________________________________
# layer_normalization_146 (LayerN (None, None, 256)    512         add_47[0][0]
# __________________________________________________________________________________________________
# re_lu_146 (ReLU)                (None, None, 256)    0           layer_normalization_146[0][0]
# __________________________________________________________________________________________________
# conv1d_147 (Conv1D)             (None, None, 64)     16384       re_lu_146[0][0]
# __________________________________________________________________________________________________
# layer_normalization_147 (LayerN (None, None, 64)     128         conv1d_147[0][0]
# __________________________________________________________________________________________________
# re_lu_147 (ReLU)                (None, None, 64)     0           layer_normalization_147[0][0]
# __________________________________________________________________________________________________
# conv1d_148 (Conv1D)             (None, None, 64)     12288       re_lu_147[0][0]
# __________________________________________________________________________________________________
# layer_normalization_148 (LayerN (None, None, 64)     128         conv1d_148[0][0]
# __________________________________________________________________________________________________
# re_lu_148 (ReLU)                (None, None, 64)     0           layer_normalization_148[0][0]
# __________________________________________________________________________________________________
# conv1d_149 (Conv1D)             (None, None, 256)    16640       re_lu_148[0][0]
# __________________________________________________________________________________________________
# add_48 (Add)                    (None, None, 256)    0           add_47[0][0]
#                                                                  conv1d_149[0][0]
# __________________________________________________________________________________________________
# layer_normalization_149 (LayerN (None, None, 256)    512         add_48[0][0]
# __________________________________________________________________________________________________
# re_lu_149 (ReLU)                (None, None, 256)    0           layer_normalization_149[0][0]
# __________________________________________________________________________________________________
# conv1d_150 (Conv1D)             (None, None, 64)     16384       re_lu_149[0][0]
# __________________________________________________________________________________________________
# layer_normalization_150 (LayerN (None, None, 64)     128         conv1d_150[0][0]
# __________________________________________________________________________________________________
# re_lu_150 (ReLU)                (None, None, 64)     0           layer_normalization_150[0][0]
# __________________________________________________________________________________________________
# conv1d_151 (Conv1D)             (None, None, 64)     12288       re_lu_150[0][0]
# __________________________________________________________________________________________________
# layer_normalization_151 (LayerN (None, None, 64)     128         conv1d_151[0][0]
# __________________________________________________________________________________________________
# re_lu_151 (ReLU)                (None, None, 64)     0           layer_normalization_151[0][0]
# __________________________________________________________________________________________________
# conv1d_152 (Conv1D)             (None, None, 256)    16640       re_lu_151[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, None, 256)    0           add_48[0][0]
#                                                                  conv1d_152[0][0]
# __________________________________________________________________________________________________
# layer_normalization_152 (LayerN (None, None, 256)    512         add_49[0][0]
# __________________________________________________________________________________________________
# re_lu_152 (ReLU)                (None, None, 256)    0           layer_normalization_152[0][0]
# __________________________________________________________________________________________________
# conv1d_153 (Conv1D)             (None, None, 64)     16384       re_lu_152[0][0]
# __________________________________________________________________________________________________
# layer_normalization_153 (LayerN (None, None, 64)     128         conv1d_153[0][0]
# __________________________________________________________________________________________________
# re_lu_153 (ReLU)                (None, None, 64)     0           layer_normalization_153[0][0]
# __________________________________________________________________________________________________
# conv1d_154 (Conv1D)             (None, None, 64)     12288       re_lu_153[0][0]
# __________________________________________________________________________________________________
# layer_normalization_154 (LayerN (None, None, 64)     128         conv1d_154[0][0]
# __________________________________________________________________________________________________
# re_lu_154 (ReLU)                (None, None, 64)     0           layer_normalization_154[0][0]
# __________________________________________________________________________________________________
# conv1d_155 (Conv1D)             (None, None, 256)    16640       re_lu_154[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, None, 256)    0           add_49[0][0]
#                                                                  conv1d_155[0][0]
# __________________________________________________________________________________________________
# layer_normalization_155 (LayerN (None, None, 256)    512         add_50[0][0]
# __________________________________________________________________________________________________
# re_lu_155 (ReLU)                (None, None, 256)    0           layer_normalization_155[0][0]
# __________________________________________________________________________________________________
# conv1d_156 (Conv1D)             (None, None, 64)     16384       re_lu_155[0][0]
# __________________________________________________________________________________________________
# layer_normalization_156 (LayerN (None, None, 64)     128         conv1d_156[0][0]
# __________________________________________________________________________________________________
# re_lu_156 (ReLU)                (None, None, 64)     0           layer_normalization_156[0][0]
# __________________________________________________________________________________________________
# conv1d_157 (Conv1D)             (None, None, 64)     12288       re_lu_156[0][0]
# __________________________________________________________________________________________________
# layer_normalization_157 (LayerN (None, None, 64)     128         conv1d_157[0][0]
# __________________________________________________________________________________________________
# re_lu_157 (ReLU)                (None, None, 64)     0           layer_normalization_157[0][0]
# __________________________________________________________________________________________________
# conv1d_158 (Conv1D)             (None, None, 256)    16640       re_lu_157[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, None, 256)    0           add_50[0][0]
#                                                                  conv1d_158[0][0]
# __________________________________________________________________________________________________
# layer_normalization_158 (LayerN (None, None, 256)    512         add_51[0][0]
# __________________________________________________________________________________________________
# re_lu_158 (ReLU)                (None, None, 256)    0           layer_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv1d_159 (Conv1D)             (None, None, 64)     16384       re_lu_158[0][0]
# __________________________________________________________________________________________________
# layer_normalization_159 (LayerN (None, None, 64)     128         conv1d_159[0][0]
# __________________________________________________________________________________________________
# re_lu_159 (ReLU)                (None, None, 64)     0           layer_normalization_159[0][0]
# __________________________________________________________________________________________________
# conv1d_160 (Conv1D)             (None, None, 64)     12288       re_lu_159[0][0]
# __________________________________________________________________________________________________
# layer_normalization_160 (LayerN (None, None, 64)     128         conv1d_160[0][0]
# __________________________________________________________________________________________________
# re_lu_160 (ReLU)                (None, None, 64)     0           layer_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv1d_161 (Conv1D)             (None, None, 256)    16640       re_lu_160[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, None, 256)    0           add_51[0][0]
#                                                                  conv1d_161[0][0]
# __________________________________________________________________________________________________
# layer_normalization_161 (LayerN (None, None, 256)    512         add_52[0][0]
# __________________________________________________________________________________________________
# re_lu_161 (ReLU)                (None, None, 256)    0           layer_normalization_161[0][0]
# __________________________________________________________________________________________________
# conv1d_162 (Conv1D)             (None, None, 64)     16384       re_lu_161[0][0]
# __________________________________________________________________________________________________
# layer_normalization_162 (LayerN (None, None, 64)     128         conv1d_162[0][0]
# __________________________________________________________________________________________________
# re_lu_162 (ReLU)                (None, None, 64)     0           layer_normalization_162[0][0]
# __________________________________________________________________________________________________
# conv1d_163 (Conv1D)             (None, None, 64)     12288       re_lu_162[0][0]
# __________________________________________________________________________________________________
# layer_normalization_163 (LayerN (None, None, 64)     128         conv1d_163[0][0]
# __________________________________________________________________________________________________
# re_lu_163 (ReLU)                (None, None, 64)     0           layer_normalization_163[0][0]
# __________________________________________________________________________________________________
# conv1d_164 (Conv1D)             (None, None, 256)    16640       re_lu_163[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, None, 256)    0           add_52[0][0]
#                                                                  conv1d_164[0][0]
# __________________________________________________________________________________________________
# layer_normalization_164 (LayerN (None, None, 256)    512         add_53[0][0]
# __________________________________________________________________________________________________
# re_lu_164 (ReLU)                (None, None, 256)    0           layer_normalization_164[0][0]
# __________________________________________________________________________________________________
# conv1d_165 (Conv1D)             (None, None, 64)     16384       re_lu_164[0][0]
# __________________________________________________________________________________________________
# layer_normalization_165 (LayerN (None, None, 64)     128         conv1d_165[0][0]
# __________________________________________________________________________________________________
# re_lu_165 (ReLU)                (None, None, 64)     0           layer_normalization_165[0][0]
# __________________________________________________________________________________________________
# conv1d_166 (Conv1D)             (None, None, 64)     12288       re_lu_165[0][0]
# __________________________________________________________________________________________________
# layer_normalization_166 (LayerN (None, None, 64)     128         conv1d_166[0][0]
# __________________________________________________________________________________________________
# re_lu_166 (ReLU)                (None, None, 64)     0           layer_normalization_166[0][0]
# __________________________________________________________________________________________________
# conv1d_167 (Conv1D)             (None, None, 256)    16640       re_lu_166[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, None, 256)    0           add_53[0][0]
#                                                                  conv1d_167[0][0]
# __________________________________________________________________________________________________
# layer_normalization_167 (LayerN (None, None, 256)    512         add_54[0][0]
# __________________________________________________________________________________________________
# re_lu_167 (ReLU)                (None, None, 256)    0           layer_normalization_167[0][0]
# __________________________________________________________________________________________________
# conv1d_168 (Conv1D)             (None, None, 64)     16384       re_lu_167[0][0]
# __________________________________________________________________________________________________
# layer_normalization_168 (LayerN (None, None, 64)     128         conv1d_168[0][0]
# __________________________________________________________________________________________________
# re_lu_168 (ReLU)                (None, None, 64)     0           layer_normalization_168[0][0]
# __________________________________________________________________________________________________
# conv1d_169 (Conv1D)             (None, None, 64)     12288       re_lu_168[0][0]
# __________________________________________________________________________________________________
# layer_normalization_169 (LayerN (None, None, 64)     128         conv1d_169[0][0]
# __________________________________________________________________________________________________
# re_lu_169 (ReLU)                (None, None, 64)     0           layer_normalization_169[0][0]
# __________________________________________________________________________________________________
# conv1d_170 (Conv1D)             (None, None, 256)    16640       re_lu_169[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, None, 256)    0           add_54[0][0]
#                                                                  conv1d_170[0][0]
# __________________________________________________________________________________________________
# layer_normalization_170 (LayerN (None, None, 256)    512         add_55[0][0]
# __________________________________________________________________________________________________
# re_lu_170 (ReLU)                (None, None, 256)    0           layer_normalization_170[0][0]
# __________________________________________________________________________________________________
# conv1d_171 (Conv1D)             (None, None, 64)     16384       re_lu_170[0][0]
# __________________________________________________________________________________________________
# layer_normalization_171 (LayerN (None, None, 64)     128         conv1d_171[0][0]
# __________________________________________________________________________________________________
# re_lu_171 (ReLU)                (None, None, 64)     0           layer_normalization_171[0][0]
# __________________________________________________________________________________________________
# conv1d_172 (Conv1D)             (None, None, 64)     12288       re_lu_171[0][0]
# __________________________________________________________________________________________________
# layer_normalization_172 (LayerN (None, None, 64)     128         conv1d_172[0][0]
# __________________________________________________________________________________________________
# re_lu_172 (ReLU)                (None, None, 64)     0           layer_normalization_172[0][0]
# __________________________________________________________________________________________________
# conv1d_173 (Conv1D)             (None, None, 256)    16640       re_lu_172[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, None, 256)    0           add_55[0][0]
#                                                                  conv1d_173[0][0]
# __________________________________________________________________________________________________
# layer_normalization_173 (LayerN (None, None, 256)    512         add_56[0][0]
# __________________________________________________________________________________________________
# re_lu_173 (ReLU)                (None, None, 256)    0           layer_normalization_173[0][0]
# __________________________________________________________________________________________________
# conv1d_174 (Conv1D)             (None, None, 64)     16384       re_lu_173[0][0]
# __________________________________________________________________________________________________
# layer_normalization_174 (LayerN (None, None, 64)     128         conv1d_174[0][0]
# __________________________________________________________________________________________________
# re_lu_174 (ReLU)                (None, None, 64)     0           layer_normalization_174[0][0]
# __________________________________________________________________________________________________
# conv1d_175 (Conv1D)             (None, None, 64)     12288       re_lu_174[0][0]
# __________________________________________________________________________________________________
# layer_normalization_175 (LayerN (None, None, 64)     128         conv1d_175[0][0]
# __________________________________________________________________________________________________
# re_lu_175 (ReLU)                (None, None, 64)     0           layer_normalization_175[0][0]
# __________________________________________________________________________________________________
# conv1d_176 (Conv1D)             (None, None, 256)    16640       re_lu_175[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, None, 256)    0           add_56[0][0]
#                                                                  conv1d_176[0][0]
# __________________________________________________________________________________________________
# layer_normalization_176 (LayerN (None, None, 256)    512         add_57[0][0]
# __________________________________________________________________________________________________
# re_lu_176 (ReLU)                (None, None, 256)    0           layer_normalization_176[0][0]
# __________________________________________________________________________________________________
# conv1d_177 (Conv1D)             (None, None, 64)     16384       re_lu_176[0][0]
# __________________________________________________________________________________________________
# layer_normalization_177 (LayerN (None, None, 64)     128         conv1d_177[0][0]
# __________________________________________________________________________________________________
# re_lu_177 (ReLU)                (None, None, 64)     0           layer_normalization_177[0][0]
# __________________________________________________________________________________________________
# conv1d_178 (Conv1D)             (None, None, 64)     12288       re_lu_177[0][0]
# __________________________________________________________________________________________________
# layer_normalization_178 (LayerN (None, None, 64)     128         conv1d_178[0][0]
# __________________________________________________________________________________________________
# re_lu_178 (ReLU)                (None, None, 64)     0           layer_normalization_178[0][0]
# __________________________________________________________________________________________________
# conv1d_179 (Conv1D)             (None, None, 256)    16640       re_lu_178[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, None, 256)    0           add_57[0][0]
#                                                                  conv1d_179[0][0]
# __________________________________________________________________________________________________
# layer_normalization_179 (LayerN (None, None, 256)    512         add_58[0][0]
# __________________________________________________________________________________________________
# re_lu_179 (ReLU)                (None, None, 256)    0           layer_normalization_179[0][0]
# __________________________________________________________________________________________________
# conv1d_180 (Conv1D)             (None, None, 64)     16384       re_lu_179[0][0]
# __________________________________________________________________________________________________
# layer_normalization_180 (LayerN (None, None, 64)     128         conv1d_180[0][0]
# __________________________________________________________________________________________________
# re_lu_180 (ReLU)                (None, None, 64)     0           layer_normalization_180[0][0]
# __________________________________________________________________________________________________
# conv1d_181 (Conv1D)             (None, None, 64)     12288       re_lu_180[0][0]
# __________________________________________________________________________________________________
# layer_normalization_181 (LayerN (None, None, 64)     128         conv1d_181[0][0]
# __________________________________________________________________________________________________
# re_lu_181 (ReLU)                (None, None, 64)     0           layer_normalization_181[0][0]
# __________________________________________________________________________________________________
# conv1d_182 (Conv1D)             (None, None, 256)    16640       re_lu_181[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, None, 256)    0           add_58[0][0]
#                                                                  conv1d_182[0][0]
# __________________________________________________________________________________________________
# layer_normalization_182 (LayerN (None, None, 256)    512         add_59[0][0]
# __________________________________________________________________________________________________
# re_lu_182 (ReLU)                (None, None, 256)    0           layer_normalization_182[0][0]
# __________________________________________________________________________________________________
# conv1d_183 (Conv1D)             (None, None, 64)     16384       re_lu_182[0][0]
# __________________________________________________________________________________________________
# layer_normalization_183 (LayerN (None, None, 64)     128         conv1d_183[0][0]
# __________________________________________________________________________________________________
# re_lu_183 (ReLU)                (None, None, 64)     0           layer_normalization_183[0][0]
# __________________________________________________________________________________________________
# conv1d_184 (Conv1D)             (None, None, 64)     12288       re_lu_183[0][0]
# __________________________________________________________________________________________________
# layer_normalization_184 (LayerN (None, None, 64)     128         conv1d_184[0][0]
# __________________________________________________________________________________________________
# re_lu_184 (ReLU)                (None, None, 64)     0           layer_normalization_184[0][0]
# __________________________________________________________________________________________________
# conv1d_185 (Conv1D)             (None, None, 256)    16640       re_lu_184[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, None, 256)    0           add_59[0][0]
#                                                                  conv1d_185[0][0]
# __________________________________________________________________________________________________
# layer_normalization_185 (LayerN (None, None, 256)    512         add_60[0][0]
# __________________________________________________________________________________________________
# re_lu_185 (ReLU)                (None, None, 256)    0           layer_normalization_185[0][0]
# __________________________________________________________________________________________________
# conv1d_186 (Conv1D)             (None, None, 64)     16384       re_lu_185[0][0]
# __________________________________________________________________________________________________
# layer_normalization_186 (LayerN (None, None, 64)     128         conv1d_186[0][0]
# __________________________________________________________________________________________________
# re_lu_186 (ReLU)                (None, None, 64)     0           layer_normalization_186[0][0]
# __________________________________________________________________________________________________
# conv1d_187 (Conv1D)             (None, None, 64)     12288       re_lu_186[0][0]
# __________________________________________________________________________________________________
# layer_normalization_187 (LayerN (None, None, 64)     128         conv1d_187[0][0]
# __________________________________________________________________________________________________
# re_lu_187 (ReLU)                (None, None, 64)     0           layer_normalization_187[0][0]
# __________________________________________________________________________________________________
# conv1d_188 (Conv1D)             (None, None, 256)    16640       re_lu_187[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, None, 256)    0           add_60[0][0]
#                                                                  conv1d_188[0][0]
# __________________________________________________________________________________________________
# layer_normalization_188 (LayerN (None, None, 256)    512         add_61[0][0]
# __________________________________________________________________________________________________
# re_lu_188 (ReLU)                (None, None, 256)    0           layer_normalization_188[0][0]
# __________________________________________________________________________________________________
# conv1d_189 (Conv1D)             (None, None, 64)     16384       re_lu_188[0][0]
# __________________________________________________________________________________________________
# layer_normalization_189 (LayerN (None, None, 64)     128         conv1d_189[0][0]
# __________________________________________________________________________________________________
# re_lu_189 (ReLU)                (None, None, 64)     0           layer_normalization_189[0][0]
# ...
# __________________________________________________________________________________________________
# re_lu_220 (ReLU)                (None, None, 64)     0           layer_normalization_220[0][0]
# __________________________________________________________________________________________________
# conv1d_221 (Conv1D)             (None, None, 256)    16640       re_lu_220[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, None, 256)    0           add_71[0][0]
#                                                                  conv1d_221[0][0]
# __________________________________________________________________________________________________
# layer_normalization_221 (LayerN (None, None, 256)    512         add_72[0][0]
# __________________________________________________________________________________________________
# re_lu_221 (ReLU)                (None, None, 256)    0           layer_normalization_221[0][0]
# __________________________________________________________________________________________________
# conv1d_222 (Conv1D)             (None, None, 64)     16384       re_lu_221[0][0]
# __________________________________________________________________________________________________
# layer_normalization_222 (LayerN (None, None, 64)     128         conv1d_222[0][0]
# __________________________________________________________________________________________________
# re_lu_222 (ReLU)                (None, None, 64)     0           layer_normalization_222[0][0]
# __________________________________________________________________________________________________
# conv1d_223 (Conv1D)             (None, None, 64)     12288       re_lu_222[0][0]
# __________________________________________________________________________________________________
# layer_normalization_223 (LayerN (None, None, 64)     128         conv1d_223[0][0]
# __________________________________________________________________________________________________
# re_lu_223 (ReLU)                (None, None, 64)     0           layer_normalization_223[0][0]
# __________________________________________________________________________________________________
# conv1d_224 (Conv1D)             (None, None, 256)    16640       re_lu_223[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, None, 256)    0           add_72[0][0]
#                                                                  conv1d_224[0][0]
# __________________________________________________________________________________________________
# layer_normalization_224 (LayerN (None, None, 256)    512         add_73[0][0]
# __________________________________________________________________________________________________
# re_lu_224 (ReLU)                (None, None, 256)    0           layer_normalization_224[0][0]
# __________________________________________________________________________________________________
# conv1d_225 (Conv1D)             (None, None, 64)     16384       re_lu_224[0][0]
# __________________________________________________________________________________________________
# layer_normalization_225 (LayerN (None, None, 64)     128         conv1d_225[0][0]
# __________________________________________________________________________________________________
# re_lu_225 (ReLU)                (None, None, 64)     0           layer_normalization_225[0][0]
# __________________________________________________________________________________________________
# conv1d_226 (Conv1D)             (None, None, 64)     12288       re_lu_225[0][0]
# __________________________________________________________________________________________________
# layer_normalization_226 (LayerN (None, None, 64)     128         conv1d_226[0][0]
# __________________________________________________________________________________________________
# re_lu_226 (ReLU)                (None, None, 64)     0           layer_normalization_226[0][0]
# __________________________________________________________________________________________________
# conv1d_227 (Conv1D)             (None, None, 256)    16640       re_lu_226[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, None, 256)    0           add_73[0][0]
#                                                                  conv1d_227[0][0]
# __________________________________________________________________________________________________
# layer_normalization_227 (LayerN (None, None, 256)    512         add_74[0][0]
# __________________________________________________________________________________________________
# re_lu_227 (ReLU)                (None, None, 256)    0           layer_normalization_227[0][0]
# __________________________________________________________________________________________________
# conv1d_228 (Conv1D)             (None, None, 64)     16384       re_lu_227[0][0]
# __________________________________________________________________________________________________
# layer_normalization_228 (LayerN (None, None, 64)     128         conv1d_228[0][0]
# __________________________________________________________________________________________________
# re_lu_228 (ReLU)                (None, None, 64)     0           layer_normalization_228[0][0]
# __________________________________________________________________________________________________
# conv1d_229 (Conv1D)             (None, None, 64)     12288       re_lu_228[0][0]
# __________________________________________________________________________________________________
# layer_normalization_229 (LayerN (None, None, 64)     128         conv1d_229[0][0]
# __________________________________________________________________________________________________
# re_lu_229 (ReLU)                (None, None, 64)     0           layer_normalization_229[0][0]
# __________________________________________________________________________________________________
# conv1d_230 (Conv1D)             (None, None, 256)    16640       re_lu_229[0][0]
# __________________________________________________________________________________________________
# add_75 (Add)                    (None, None, 256)    0           add_74[0][0]
#                                                                  conv1d_230[0][0]
# __________________________________________________________________________________________________
# layer_normalization_230 (LayerN (None, None, 256)    512         add_75[0][0]
# __________________________________________________________________________________________________
# re_lu_230 (ReLU)                (None, None, 256)    0           layer_normalization_230[0][0]
# __________________________________________________________________________________________________
# conv1d_231 (Conv1D)             (None, None, 64)     16384       re_lu_230[0][0]
# __________________________________________________________________________________________________
# layer_normalization_231 (LayerN (None, None, 64)     128         conv1d_231[0][0]
# __________________________________________________________________________________________________
# re_lu_231 (ReLU)                (None, None, 64)     0           layer_normalization_231[0][0]
# __________________________________________________________________________________________________
# conv1d_232 (Conv1D)             (None, None, 64)     12288       re_lu_231[0][0]
# __________________________________________________________________________________________________
# layer_normalization_232 (LayerN (None, None, 64)     128         conv1d_232[0][0]
# __________________________________________________________________________________________________
# re_lu_232 (ReLU)                (None, None, 64)     0           layer_normalization_232[0][0]
# __________________________________________________________________________________________________
# conv1d_233 (Conv1D)             (None, None, 256)    16640       re_lu_232[0][0]
# __________________________________________________________________________________________________
# add_76 (Add)                    (None, None, 256)    0           add_75[0][0]
#                                                                  conv1d_233[0][0]
# __________________________________________________________________________________________________
# layer_normalization_233 (LayerN (None, None, 256)    512         add_76[0][0]
# __________________________________________________________________________________________________
# re_lu_233 (ReLU)                (None, None, 256)    0           layer_normalization_233[0][0]
# __________________________________________________________________________________________________
# conv1d_234 (Conv1D)             (None, None, 64)     16384       re_lu_233[0][0]
# __________________________________________________________________________________________________
# layer_normalization_234 (LayerN (None, None, 64)     128         conv1d_234[0][0]
# __________________________________________________________________________________________________
# re_lu_234 (ReLU)                (None, None, 64)     0           layer_normalization_234[0][0]
# __________________________________________________________________________________________________
# conv1d_235 (Conv1D)             (None, None, 64)     12288       re_lu_234[0][0]
# __________________________________________________________________________________________________
# layer_normalization_235 (LayerN (None, None, 64)     128         conv1d_235[0][0]
# __________________________________________________________________________________________________
# re_lu_235 (ReLU)                (None, None, 64)     0           layer_normalization_235[0][0]
# __________________________________________________________________________________________________
# conv1d_236 (Conv1D)             (None, None, 256)    16640       re_lu_235[0][0]
# __________________________________________________________________________________________________
# add_77 (Add)                    (None, None, 256)    0           add_76[0][0]
#                                                                  conv1d_236[0][0]
# __________________________________________________________________________________________________
# layer_normalization_236 (LayerN (None, None, 256)    512         add_77[0][0]
# __________________________________________________________________________________________________
# re_lu_236 (ReLU)                (None, None, 256)    0           layer_normalization_236[0][0]
# __________________________________________________________________________________________________
# conv1d_237 (Conv1D)             (None, None, 64)     16384       re_lu_236[0][0]
# __________________________________________________________________________________________________
# layer_normalization_237 (LayerN (None, None, 64)     128         conv1d_237[0][0]
# __________________________________________________________________________________________________
# re_lu_237 (ReLU)                (None, None, 64)     0           layer_normalization_237[0][0]
# __________________________________________________________________________________________________
# conv1d_238 (Conv1D)             (None, None, 64)     12288       re_lu_237[0][0]
# __________________________________________________________________________________________________
# layer_normalization_238 (LayerN (None, None, 64)     128         conv1d_238[0][0]
# __________________________________________________________________________________________________
# re_lu_238 (ReLU)                (None, None, 64)     0           layer_normalization_238[0][0]
# __________________________________________________________________________________________________
# conv1d_239 (Conv1D)             (None, None, 256)    16640       re_lu_238[0][0]
# __________________________________________________________________________________________________
# add_78 (Add)                    (None, None, 256)    0           add_77[0][0]
#                                                                  conv1d_239[0][0]
# __________________________________________________________________________________________________
# layer_normalization_239 (LayerN (None, None, 256)    512         add_78[0][0]
# __________________________________________________________________________________________________
# re_lu_239 (ReLU)                (None, None, 256)    0           layer_normalization_239[0][0]
# __________________________________________________________________________________________________
# conv1d_240 (Conv1D)             (None, None, 64)     16384       re_lu_239[0][0]
# __________________________________________________________________________________________________
# layer_normalization_240 (LayerN (None, None, 64)     128         conv1d_240[0][0]
# __________________________________________________________________________________________________
# re_lu_240 (ReLU)                (None, None, 64)     0           layer_normalization_240[0][0]
# __________________________________________________________________________________________________
# conv1d_241 (Conv1D)             (None, None, 64)     12288       re_lu_240[0][0]
# __________________________________________________________________________________________________
# layer_normalization_241 (LayerN (None, None, 64)     128         conv1d_241[0][0]
# __________________________________________________________________________________________________
# re_lu_241 (ReLU)                (None, None, 64)     0           layer_normalization_241[0][0]
# __________________________________________________________________________________________________
# conv1d_242 (Conv1D)             (None, None, 256)    16640       re_lu_241[0][0]
# __________________________________________________________________________________________________
# add_79 (Add)                    (None, None, 256)    0           add_78[0][0]
#                                                                  conv1d_242[0][0]
# __________________________________________________________________________________________________
# conv1d_243 (Conv1D)             (None, None, 257)    66049       add_79[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, 257)    0           conv1d_243[0][0]
# ==================================================================================================
# Total params: 1,975,553
# Trainable params: 1,975,553
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Loading sample statistics...

# %%
# perform inference with the above mentioned 'model_variables' and 'path variables' 
deepxi.infer(test_x=test_x,test_x_len=test_x_len,test_x_base_names=test_x_base_names,out_path= out_path)
# Out:
# 100%|██████████| 2/2 [00:00<00:00, 82.71it/s]
# Processing observations...
# Performing inference...
# 2/2 [==============================] - 3s 91ms/step
# 100%|██████████| 2/2 [00:00<00:00,  6.74it/s]

# %%
import soundfile as sf
from pydub import AudioSegment

# %%
sound = AudioSegment.from_file('/content/gdrive/MyDrive/DEEP/DeepXi/set/test_noisy_speech/y2mate.com - modi on indira 1min 19 sec_144p.3gp')
sound = sound.set_channels(1)
sound.export("/content/gdrive/MyDrive/DEEP/DeepXi/set/test_noisy_speech/y2.wav", format="wav")
# Out:
# <_io.BufferedRandom name='/content/gdrive/MyDrive/DEEP/DeepXi/set/test_noisy_speech/y2.wav'>

# %%
# import moviepy.editor as mp
# clip = mp.VideoFileClip("/content/gdrive/MyDrive/shubham_video/y2mate.com - Switzerland in one minute 🎬_480p.mp4")
# clip.audio.write_audiofile("/content/gdrive/MyDrive/shubham_video/theaudio.mp3")

# %%
# from pydub import AudioSegment
# sound = AudioSegment.from_wav("/content/gdrive/MyDrive/DEEP/DeepXi/set/test_noisy_speech/2.wav")
# sound = sound.set_channels(1)
# sound.export("/content/gdrive/MyDrive/DEEP/DeepXi/set/test_noisy_speech/2.wav", format="wav")

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/DEEP/DeepXi
