# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/DELG_SK/'
# Out:
# /content/gdrive/My Drive/DELG_SK

# %%
# clone
# !git clone 'https://github.com/tensorflow/models.git'
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 46839, done.
# remote: Total 46839 (delta 0), reused 0 (delta 0), pack-reused 46839
# Receiving objects: 100% (46839/46839), 551.52 MiB | 15.24 MiB/s, done.
# Resolving deltas: 100% (32201/32201), done.
# Checking out files: 100% (2134/2134), done.

# %%
# set to this directory for importing delf library
# %cd '/content/gdrive/My Drive/DELG_SK/models/research/delf/delf/python/training/'
# Out:
# /content/gdrive/My Drive/DELG_SK/models/research/delf/delf/python/training

# %%
# !bash install_delf.sh
# Out:
# Installing TensorFlow 2.2
# Requirement already up-to-date: tensorflow==2.2.0 in /usr/local/lib/python3.6/dist-packages (2.2.0)
# ...
# Installing TensorFlow 2.2 for GPU
# Requirement already up-to-date: tensorflow-gpu==2.2.0 in /usr/local/lib/python3.6/dist-packages (2.2.0)
# ...
# Installing TF-Slim from source:
# Cloning into 'tf-slim'...
# remote: Enumerating objects: 627, done.
# remote: Total 627 (delta 0), reused 0 (delta 0), pack-reused 627
# Receiving objects: 100% (627/627), 531.47 KiB | 4.22 MiB/s, done.
# Resolving deltas: 100% (440/440), done.
# Processing /content/gdrive/My Drive/DELG_SK/models/research/delf/delf/python/training/tf-slim
# ...
#   Created wheel for tf-slim: filename=tf_slim-1.2.0-cp36-none-any.whl size=360911 sha256=eb200a7533f3858291dd7cc7a26ec714bb4efe68c7855ca8d3f04f414bff7e9c
#   Stored in directory: /root/.cache/pip/wheels/bc/b8/04/8e8e77cd31910717ae36e1e1f8a64fa7ba005cf283566b92f7
# Successfully built tf-slim
# ...
#   Found existing installation: tf-slim 1.2.0
# ...

# %%
import d

# %%
# %cd '/content/gdrive/My Drive/DELG_SK/models/research/delf/delf/python/delg'
# Out:
# /content/gdrive/My Drive/DELG_SK/models/research/delf/delf/python/delg

# %%
mkdir parameters && cd parameters

# %%
# R50-DELG-GLD model.
# !wget http://storage.googleapis.com/delf/r50delg_gld_20200814.tar.gz
# !tar -xvzf r50delg_gld_20200814.tar.gz
# Out:
# --2020-11-06 12:18:42--  http://storage.googleapis.com/delf/r50delg_gld_20200814.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.26.128, 172.217.193.128, 172.217.204.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.26.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 106082379 (101M) [application/x-gzip]
# Saving to: ‘r50delg_gld_20200814.tar.gz’
#
# r50delg_gld_2020081 100%[===================>] 101.17M  62.9MB/s    in 1.6s
#
# 2020-11-06 12:18:44 (62.9 MB/s) - ‘r50delg_gld_20200814.tar.gz’ saved [106082379/106082379]
#
# r50delg_gld_20200814/
# r50delg_gld_20200814/saved_model.pb
# r50delg_gld_20200814/variables/
# r50delg_gld_20200814/variables/variables.data-00000-of-00001
# r50delg_gld_20200814/variables/variables.index

# %%
# %cd '/content/gdrive/My Drive/DELG_SK/models/research/delf/delf/python/delg/'
# Out:
# /content/gdrive/My Drive/DELG_SK/models/research/delf/delf/python/delg

# %%
# !python3 extract_features.py \
  --delf_config_path r50delg_gld_config.pbtxt \
  --dataset_file_path '/content/gdrive/My Drive/DELG1/models/research/delf/delf/python/training/gnd_roxford5k.mat' \
  --images_dir '/content/gdrive/My Drive/DELG1/models/research/delf/delf/python/training/oxford5k_images' \
  --image_set query \
  --output_features_dir '/content/gdrive/My Drive/DELG_NEW/models'
# Out:
# Traceback (most recent call last):
#   File "extract_features.py", line 40, in <module>
#     from delf import delf_config_pb2
# ModuleNotFoundError: No module named 'delf'
