# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#%cd '/content/gdrive/My Drive/NEW_WAY'
#!git clone https://github.com/anicolson/DeepXi.git
#!sudo apt-get install sox

# %%
# %cd '/content/gdrive/My Drive/NEW_WAY/DeepXi'
# Out:
# /content/gdrive/My Drive/NEW_WAY/DeepXi

# %%
#%cd '/content/gdrive/My Drive/NEW_WAY/DeepXi/set/test_noisy_speech'
#!sox libero_test_with_absence.wav -r 16000 -b 32 -c 1  new1.wav
#!sox --i '/content/gdrive/My Drive/NEW_WAY/DeepXi/set/test_noisy_speech/new1.wav'
# Out:
# /content/gdrive/My Drive/NEW_WAY/DeepXi/set/test_noisy_speech
# sox WARN rate: rate clipped 1 samples; decrease volume?

# %%
#!pip install soundfil, pesq, pystoi,Cython
# !pip install pystoi
# !pip install Cython
# Out:
# ...
#   Created wheel for pystoi: filename=pystoi-0.3.3-py2.py3-none-any.whl size=7782 sha256=d2e0005edcb3729e7224f75a87e1e2b414b6509c45baf79bbedec15abde0162e
#   Stored in directory: /root/.cache/pip/wheels/6b/6c/b2/d49af4b7ee4ce275cf2511484b043e09b9cb7ae90c1accb17a
# Successfully built pystoi
# ...

# %%
# !ls
# Out:
# 1-s2.0-S0167639318304308-main.pdf  fig_training_example.png  requirements.txt
# data				   fig_xi_dist.png	     run_demand_vb.sh
# deepxi				   LICENSE.txt		     run.m
# eval_example.m			   log			     run.sh
# eval_stats.m			   main.py		     seq_mask_batch.mat
# fig_Deep-Xi-ResNet.png		   model		     set
# fig_front-end.png		   out			     xi_bar_batch.mat
# fig_tcn.gif			   README.md		     x_STMS_batch.mat

# %%
#%cd '/content/gdrive/My Drive/NEW_WAY/DeepXi'
#!bash ./run.sh VER="resnet-1.0c" INFER=1 GAIN="mmse-lsa"
# %cd '/content/gdrive/My Drive/NEW_WAY/DeepXi/deepxi'
#! python gain.py
! python model.py
# Out:
# /content/gdrive/My Drive/NEW_WAY/DeepXi/deepxi
#   File "model.py", line 280
#     print('hello new')
#                              ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
#%cd '/content/gdrive/My Drive/NEW_WAY/DeepXi'
#!bash run.sh
