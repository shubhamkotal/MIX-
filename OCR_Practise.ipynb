# %%
from google.colab import drive
drive.mount('/content/gdrive')  #mounting
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········

# %%
# %cd '/content/gdrive/My Drive/OCR/CUTIE'
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/My Drive/OCR/CUTIE'
# /content

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
# !pip install pyparsing==2.3.0
# !pip install pytest==4.1.1
# !pip install python-dateutil==2.7.5
# !pip install pytz==2018.7
# !pip install requests==2.21.0
# !pip install scipy==1.2.0
# !pip install six==1.12.0
# !pip install tensorboard==1.12.1
# !pip install tensorflow==1.12.0
# !pip install termcolor==1.1.0
# !pip install urllib3==1.24.1
# !pip install Werkzeug==0.14.1
# !pip install tokenization
# Out:
# ...
#      |████████████████████████████████| 61kB 1.9MB/s
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: pyparsing 2.4.7
#     Uninstalling pyparsing-2.4.7:
#       Successfully uninstalled pyparsing-2.4.7
# ...
#      |████████████████████████████████| 225kB 2.8MB/s
# ...
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ...
#   Found existing installation: pytest 3.6.4
#     Uninstalling pytest-3.6.4:
#       Successfully uninstalled pytest-3.6.4
# ...
#      |████████████████████████████████| 235kB 2.8MB/s
# ...
# ERROR: fbprophet 0.6 has requirement python-dateutil>=2.8.0, but you'll have python-dateutil 2.7.5 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: python-dateutil 2.8.1
#     Uninstalling python-dateutil-2.8.1:
# ...

# %%
import tensorflow as tf
import numpy as np
import argparse, os
import timeit
from pprint import pprint
from os import walk
from os.path import isfile, join
import csv, re, random, json
from collections import defaultdict

#dataloader packages
import tokenization
import cv2
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

#utils packages
from os.path import join
try:
    import cv2
except ImportError:
    pass

#user define files
#from data_loader_json import DataLoader
#from utils import *
import math

#from model_cutie_aspp import CUTIERes as CUTIEv1
#from model_cutie2_aspp import CUTIE2 as CUTIEv2
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !python main_train_json.py '/content/gdrive/My Drive/'
# Out:
# python3: can't open file 'main_train_json.py': [Errno 2] No such file or directory

# %%
# !python main_train_json.py  --doc_path '/content/gdrive/My Drive/cuity_data_set'   --ckpt_path 'graph/'  --ckpt_file 'CUTIE_highresolution_8x_d20000c9(r80c80_iter_40000.ckpt' --tokenize True  --update_dict True  --dict_path 'dict/'  --rows_segment 72  --cols_segment 72  --augment_strategy 1  --positional_mapping_strategy 1  --rows_target 64  --cols_target 64  --rows_ulimit 80  --fill_bbox False  --data_augmentation_extra True  --data_augmentation_dropout 1  --data_augmentation_extra_rows 16  --data_augmentation_extra_cols 16  --batch_size 32  --iterations 40000  --lr_decay_step 13000  --learning_rate 0.0001  --lr_decay_factor 0.1  --hard_negative_ratio 3  --use_ghm 0  --ghm_bins 30  --ghm_momentum 0    --log_disp_step 100  --log_save_step 100  --validation_step 100  --test_step 400  --ckpt_save_step 50  --embedding_size 128  --weight_decay 0.0005  --eps 1e-6
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
#python main_train_json.py  --doc_path '/content/gdrive/My Drive/cuity_data_set' --save_prefix 'INVOICE'  --test_path ''  --embedding_file ''  --ckpt_path 'graph/'  --ckpt_file 'CUTIE_highresolution_8x_d20000c9(r80c80_iter_40000.ckpt' --tokenize True  --update_dict True  --dict_path 'dict/'  --rows_segment 72  --cols_segment 72  --augment_strategy 1  --positional_mapping_strategy 1  --rows_target 64 --cols_target 64  --rows_ulimit 80  --fill_bbox False --data_augmentation_extra True --data_augmenta
