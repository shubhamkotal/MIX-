# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/MyDrive/Deeplobe GIT'
# Out:
# /content/gdrive/MyDrive/Deeplobe GIT

# %%
#!unzip '/content/gdrive/MyDrive/Deeplobe GIT/deeplobe-ai-master.zip'

# %%
ls
# Out:
# deeplobe-ai-master/  deeplobe-ai-master.zip

# %%
cd deeplobe-ai-master
# Out:
# /content/gdrive/My Drive/Deeplobe GIT/deeplobe-ai-master

# %%
ls
# Out:
# Datasets/  DATASETS.md  deeplobeai/  LICENSE  README.md  setup.py

# %%
# !pip install torch==1.0.1.post2
# Out:
# ...
#      |████████████████████████████████| 582.5MB 26kB/s
# ERROR: torchvision 0.5.0 has requirement torch==1.4.0, but you'll have torch 1.0.1.post2 which is incompatible.
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.0.1.post2 which is incompatible.
# ERROR: pytorch-lightning 1.1.7 has requirement torch>=1.3, but you'll have torch 1.0.1.post2 which is incompatible.
# ...
#   Found existing installation: torch 1.4.0
#     Uninstalling torch-1.4.0:
#       Successfully uninstalled torch-1.4.0
# ...

# %%
# !pip install pytorch== 1.4.0
# !pip install pytorch-lightning==1.1.7
# !pip install PIL == 7.0.0
# !pip install torchvision==0.5.0
# Out:
# ERROR: Could not find a version that satisfies the requirement pytorch== (from versions: 0.1.2, 1.0.2)
# ERROR: No matching distribution found for pytorch==
# ...
#      |████████████████████████████████| 696kB 19.2MB/s
# ...
#      |████████████████████████████████| 276kB 46.8MB/s
# ...
#      |████████████████████████████████| 829kB 47.6MB/s
# ...
#      |████████████████████████████████| 112kB 45.7MB/s
# ...
#      |████████████████████████████████| 1.3MB 47.1MB/s
# ...
#      |████████████████████████████████| 296kB 56.1MB/s
# ...
#      |████████████████████████████████| 143kB 37.8MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44620 sha256=97f32c414ae3b89e09572ec1719e4358d8a60578249b95ce7afd5f455627c751
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# ...
#   Created wheel for future: filename=future-0.18.2-cp37-none-any.whl size=491058 sha256=c9f47c8a832cb3b26ab566a1a914c3e7050f10965f8577c89bd30f065b784186
# ...

# %%
import deeplobeai

# %%
from deeplobeai.semantic import Semantic
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-4240d44afbce> in <module>()
# ----> 1 from deeplobeai.semantic import Semantic
#
# /content/gdrive/My Drive/Deeplobe GIT/deeplobe-ai-master/deeplobeai/semantic.py in <module>()
#       7 import torch.nn as nn
#       8 # To get MNIST data and transforms
# ----> 9 from torchvision import datasets, transforms
#      10 # To get the optimizer for our model
#      11
#
# /usr/local/lib/python3.7/dist-packages/torchvision/__init__.py in <module>()
#       1 import warnings
#       2
# ----> 3 from torchvision import models
#       4 from torchvision import datasets
#       5 from torchvision import ops
#
# /usr/local/lib/python3.7/dist-packages/torchvision/models/__init__.py in <module>()
#       3 from .vgg import *
#       4 from .squeezenet import *
# ----> 5 from .inception import *
# ...
