# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/My Drive/pdf/'
# Out:
# /content/gdrive/My Drive/pdf

# %%
import camelot

# %%
tables = camelot.read_pdf('/content/gdrive/My Drive/pdf/infosys-ar-20.pdf', pages = "1-end")

# %%
# %cd '/content/gdrive/My Drive/pdf/tables'
# Out:
# /content/gdrive/My Drive/pdf/tables

# %%
ls1=[]
for i in range(0,len(tables)):
  a=tables[i].parsing_report
  if a['whitespace']>0:
    ls1.append(a['page'])
    tables[i].to_csv("table" + str(a['page']) + ".csv")

# %%
ls1=list(set(ls1))
ls1.sort()

# %%
print(ls1)
# Out:
# [1, 4, 8, 16, 22, 23, 101, 102, 103, 104, 105, 110, 113, 117, 119, 120, 122, 123, 126, 129, 130, 131, 134, 139, 141, 161, 162, 163, 223, 224, 225, 226, 227, 290, 291, 306, 310]
