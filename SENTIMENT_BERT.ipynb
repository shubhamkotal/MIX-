# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/MyDrive/sentiments'
# Out:
# /content/gdrive/MyDrive/sentiments

# %%
#!git clone 'https://github.com/zymlnlp/Tweets-Sentiment-Analysis.git'

# %%
from flask import abort, Flask, request
from flair.models import TextClassifier
from flair.data import Sentence
from flask import render_template

# %%
#!pip install flair

# %%
classifier = TextClassifier.load('en-sentiment')
# Out:
# 2020-12-08 06:50:55,401 https://nlp.informatik.hu-berlin.de/resources/models/sentiment-curated-distilbert/sentiment-en-mix-distillbert_3.1.pt not found in cache, downloading to /tmp/tmppl7deop5
# 100%|██████████| 266147697/266147697 [00:46<00:00, 5723259.30B/s]
# 2020-12-08 06:51:42,731 copying /tmp/tmppl7deop5 to cache at /root/.flair/models/sentiment-en-mix-distillbert_3.1.pt
# 2020-12-08 06:51:43,541 removing temp file /tmp/tmppl7deop5
# 2020-12-08 06:51:43,573 loading file /root/.flair/models/sentiment-en-mix-distillbert_3.1.pt
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=442.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=466062.0, style=ProgressStyle(descripti…

# %%
def sentimentAnalysis(query):
    inputQuery = query
    sentence = Sentence(inputQuery)
    classifier.predict(sentence)
    print('Sentiment: ', sentence.labels)
    label = sentence.labels[0]
    labscore = (label.score)*100
    response = {'result': label.value, 'score':"%.2f" % labscore}

# %%
sentimentAnalysis()
