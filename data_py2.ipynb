# %%
from google.colab import drive
drive.mount('/content/gdrive')  #mounting
# Out:
# Mounted at /content/gdrive

# %%
import codecs
import re
import string
import nltk
import pandas as pd
import operator
from nltk import PerceptronTagger


def load_stopwords(path):
    stopwords = set([])

    for line in codecs.open(path, 'r', 'utf-8'):
        if not re.search('^#', line) and len(line.strip()) > 0:
            stopwords.add(line.strip().lower())  # lowercase

    return stopwords


def load_filler_words(path):
    with open(path, 'r+') as f:
        filler = f.read().splitlines()

    return filler


def clean_utterance(utterance, filler_words):
    utt = utterance
    # replace consecutive unigrams with a single instance
    utt = re.sub('\\b(\\w+)\\s+\\1\\b', '\\1', utt)
    # same for bigrams
    utt = re.sub('(\\b.+?\\b)\\1\\b', '\\1', utt)
    # strip extra white space
    utt = re.sub(' +', ' ', utt)
    # strip leading and trailing white space
    utt = utt.strip()

    # remove filler words # highly time-consuming
    utt = ' ' + utt + ' '
    for filler_word in filler_words:
        utt = re.sub(' ' + filler_word + ' ', ' ', utt)
        utt = re.sub(' ' + filler_word.capitalize() + ' ', ' ', utt)

    return utt

'''
def clean_text(text, stopwords, remove_stopwords=True, pos_filtering=False, stemming=True, lower_case=True):
    if lower_case:
        # convert to lower case
        text = text.lower()
    # strip extra white space
    text = re.sub(' +', ' ', text)
    # strip leading and trailing white space
    text = text.strip()
    # tokenize (split based on whitespace)
    tokens = text.split(' ')

    # remove punctuation
    tokens = [t for t in tokens if t not in string.punctuation]

    if pos_filtering:
        tagger = PerceptronTagger()
        # apply POS-tagging
        tagged_tokens = tagger.tag(tokens)
        # retain only nouns and adjectives
        tokens = [item[0] for item in tagged_tokens if item[1] in ['NN', 'NNS', 'NNP', 'NNPS', 'JJ', 'JJS', 'JJR', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']]
    if remove_stopwords:
        # remove stopwords
        tokens = [token for token in tokens if token.lower() not in stopwords]
    if stemming:
        stemmer = nltk.stem.PorterStemmer()
        # apply Porter's stemmer
        tokens_stemmed = list()
        for token in tokens:
            tokens_stemmed.append(stemmer.stem(token))
        tokens = tokens_stemmed

    return (tokens)

'''

"""
def read_ami_icsi(path, filler_words):
    asr_output = pd.read_csv(
        path,
        sep='\t',
        header=None,
        names=['ID', 'start', 'end', 'letter', 'role', 'A', 'B', 'C', 'utt']
    )

    utterances = []
    for tmp in zip(asr_output['role'].tolist(), asr_output['utt'].tolist()):
        role, utt = tmp
        for ch in ['{vocalsound}', '{gap}', '{disfmarker}', '{comment}', '{pause}', '@reject@']:
            utt = re.sub(ch, '', utt)

        utt = re.sub("'Kay", 'Okay', utt)
        utt = re.sub("'kay", 'Okay', utt)
        utt = re.sub('"Okay"', 'Okay', utt)
        utt = re.sub("'cause", 'cause', utt)
        utt = re.sub("'Cause", 'cause', utt)
        utt = re.sub('"cause"', 'cause', utt)
        utt = re.sub('"\'em"', 'them', utt)
        utt = re.sub('"\'til"', 'until', utt)
        utt = re.sub('"\'s"', 's', utt)

        # l. c. d. -> lcd
        # t. v. -> tv
        utt = re.sub('h. t. m. l.', 'html', utt)
        utt = re.sub(r"(\w)\. (\w)\. (\w)\.", r"\1\2\3", utt)
        utt = re.sub(r"(\w)\. (\w)\.", r"\1\2", utt)
        utt = re.sub(r"(\w)\.", r"\1", utt)

        # clean_utterance, remove filler_words
        utt = clean_utterance(utt, filler_words=filler_words)

        # strip extra white space
        utt = re.sub(' +', ' ', utt)
        # strip leading and trailing white space
        utt = utt.strip()

        if utt != '' and utt != '.' and utt != ' ':
            utterances.append((role, utt))

    # remove duplicate utterances per speaker
    utterances = sorted(set(utterances), key=utterances.index)
    utterances_indexed = zip(range(len(utterances)), zip(*utterances)[0], zip(*utterances)[1])

    return utterances_indexed

'''
def accumulate(iterable, func=operator.add):
    'Return running totals'
    # accumulate([1,2,3,4,5]) --> 1 3 6 10 15
    # accumulate([1,2,3,4,5], operator.mul) --> 1 2 6 24 120
    it = iter(iterable)
    try:
        total = next(it)
    except StopIteration:
        return
    yield total
    for element in it:
        total = func(total, element)
        yield total
'''   

"""
# Out:
# '\ndef read_ami_icsi(path, filler_words):\n    asr_output = pd.read_csv(\n        path,\n        sep=\'\t\',\n        header=None,\n        names=[\'ID\', \'start\', \'end\', \'letter\', \'role\', \'A\', \'B\', \'C\', \'utt\']\n    )\n\n    utterances = []\n    for tmp in zip(asr_output[\'role\'].tolist(), asr_output[\'utt\'].tolist()):\n        role, utt = tmp\n        for ch in [\'{vocalsound}\', \'{gap}\', \'{disfmarker}\', \'{comment}\', \'{pause}\', \'@reject@\']:\n            utt = re.sub(ch, \'\', utt)\n\n        utt = re.sub("\'Kay", \'Okay\', utt)\n        utt = re.sub("\'kay", \'Okay\', utt)\n        utt = re.sub(\'"Okay"\', \'Okay\', utt)\n        utt = re.sub("\'cause", \'cause\', utt)\n        utt = re.sub("\'Cause", \'cause\', utt)\n        utt = re.sub(\'"cause"\', \'cause\', utt)\n        utt = re.sub(\'"\'em"\', \'them\', utt)\n        utt = re.sub(\'"\'til"\', \'until\', utt)\n        utt = re.sub(\'"\'s"\', \'s\', utt)\n\n        # l. c. d. -> lcd\n        # t. v. -> tv\n        utt = re.sub(\'h. t. m. l.\', \'html\', utt)\n        utt = re.sub(r"(\\w)\\. (\\w)\\. (\\w)\\.", r"\x01\x02\x03", utt)\n        utt = re.sub(r"(\\w)\\. (\\w)\\.", r"\x01\x02", utt)\n        utt = re.sub(r"(\\w)\\.", r"\x01", utt)\n\n        # clean_utterance, remove filler_words\n        utt = clean_utterance(utt, filler_words=filler_words)\n\n        # strip extra white space\n        utt = re.sub(\' +\', \' \', utt)\n        # strip leading and trailing white space\n        utt = utt.strip()\n\n        if utt != \'\' and utt != \'.\' and utt != \' \':\n            utterances.append((role, utt))\n\n    # remove duplicate utterances per speaker\n    utterances = sorted(set(utterances), key=utterances.index)\n    utterances_indexed = zip(range(len(utterances)), zip(*utterances)[0], zip(*utterances)[1])\n\n    return utterances_indexed\n\n\'\'\'\ndef accumulate(iterable, func=operator.add):\n    \'Return running totals\'\n    # accumulate([1,2,3,4,5]) --> 1 3 6 10 15\n    # accumulate([1,2,3,4,5], operator.mul) --> 1 2 6 24 120\n    it = iter(iterable)\n    try:\n        total = next(it)\n    except StopIteration:\n        return\n    yield total\n    for element in it:\n        total = func(total, element)\n        yield total\n\'\'\'   \n\n'

# %%
#%cd '/content/gdrive/My Drive/summerization/Create_DATA/CoreRank/data/'

# %cd '/content/gdrive/My Drive/summerization/Create_DATA/CoreRank/data/'
# Out:
# /content/gdrive/My Drive/summerization/Create_DATA/CoreRank/data

# %%
ls
# Out:
# 'ami_params_create_community (1).gsheet'   __init__.py
#  ami_params_create_community.csv           meeting/
#  ami_params_create_community.gsheet        new
#  clustering.py                             original_reference.txt
#  clustering.pyc                            __pycache__/
#  community/                                Sample_transcript.txt
#  community_tagged/                         tf_idf.py
#  core_rank.py                              tf_idf.pyc
#  core_rank.pyc                             utils.py
#  data                                      utils.pyc
#  data1/                                    utterance/
#  dictionary_tokenizer.py                   utterance_community_detection.py

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
'''
import os
#path_to_root = '/data/'
#os.chdir(path_to_root)
import string
#import core_rank
#from data import utils
#from data import clustering
from meeting import meeting_lists
#from collections import Counter
from nltk import PerceptronTagger
#from nltk import TweetTokenizer
#from dictionary_tokenizer import DictionaryTokenizer
#from sklearn.model_selection import ParameterGrid


domain     = 'meeting' # meeting
dataset_id = 'ami'     # ami, icsi
language   = 'en'      # en
source     = 'asr'     # asr, manual

# #########################
# ### RESOURCES LOADING ###
# #########################
if domain == 'meeting':
    path_to_stopwords    = '/content/drive/My Drive/summerization/Create_DATA/CoreRank/resources/stopwords/meeting/stopwords.en.dat'
    path_to_filler_words = '/content/drive/My Drive/summerization/Create_DATA/CoreRank/resources/stopwords/meeting/filler_words.en.txt'
    stopwords = load_stopwords(path_to_stopwords)
    filler_words = load_filler_words(path_to_filler_words)

    if dataset_id == 'ami':
        ids = meeting_lists.ami_development_set + meeting_lists.ami_test_set
    elif dataset_id == 'icsi':
        ids = meeting_lists.icsi_development_set + meeting_lists.icsi_test_set

from nltk import PerceptronTagger
tagger = PerceptronTagger()


# ######################
# ### CORPUS LOADING ###
# ######################
corpus = {}
for id in ids:
    if domain == 'meeting':
        if dataset_id == 'ami' or dataset_id == 'icsi':
            if source == 'asr':
                path = 'meeting/' + dataset_id + '/' + id + '.da-asr'
            elif source == 'manual':
                path = 'meeting/' + dataset_id + '/' + id + '.da'
            # filler words will be removed during corpus loading
            corpus[id] = read_ami_icsi(path, filler_words)
'''

# %%
'''
for i in corpus[id]:
  print(i)
'''
# Out:
# '\nfor i in corpus[id]:\n  print(i)\n'

# %%
'''
# #############################
# ### CORPUS PRE-PROCESSING ###
# #############################
corpus_tagged = {}
for id in ids:
    utterances_indexed = corpus[id]
    utterances_indexed_tagged = []
    for i in range(len(utterances_indexed)):
        index, role, utt = utterances_indexed[i]

        # tokenization
        tokens = utt.split(' ')
        # tokens = tokenizer.tokenize(utt)
        corpus[id][i] = (index, role, ' '.join(tokens))  # update

        # tagging
        tokens_tagged = [tuple[0] + '/' + (tuple[1] if tuple[0] not in string.punctuation else 'PUNCT') for tuple in tagger.tag(tokens)]
        utterances_indexed_tagged.append((index, role, ' '.join(tokens_tagged)))
    corpus_tagged[id] = utterances_indexed_tagged
'''
# Out:
# "\n# #############################\n# ### CORPUS PRE-PROCESSING ###\n# #############################\ncorpus_tagged = {}\nfor id in ids:\n    utterances_indexed = corpus[id]\n    utterances_indexed_tagged = []\n    for i in range(len(utterances_indexed)):\n        index, role, utt = utterances_indexed[i]\n\n        # tokenization\n        tokens = utt.split(' ')\n        # tokens = tokenizer.tokenize(utt)\n        corpus[id][i] = (index, role, ' '.join(tokens))  # update\n\n        # tagging\n        tokens_tagged = [tuple[0] + '/' + (tuple[1] if tuple[0] not in string.punctuation else 'PUNCT') for tuple in tagger.tag(tokens)]\n        utterances_indexed_tagged.append((index, role, ' '.join(tokens_tagged)))\n    corpus_tagged[id] = utterances_indexed_tagged\n"

# %%
'''
for i,j in corpus_tagged.items():
  print(i)
'''
# Out:
# '\nfor i,j in corpus_tagged.items():\n  print(i)\n'

# %%
# !pwd
# Out:
# /content/gdrive/My Drive/summerization/Create_DATA/CoreRank/data

# %%
#asr_output = pd.read_csv("meeting/ami/TS3007d.da-asr",sep='\t',header=None,names=['ID', 'start', 'end', 'letter', 'role', 'A', 'B', 'C', 'utt'])

# %%
asr_output=pd.read_csv('/content/gdrive/My Drive/summerization/Create_DATA/CoreRank/data/Sample_transcript.txt',sep=':',names=['role','utt'])

# %%
asr_output
# Out:
#                       role                                                utt
# 0        Chairman Wormsley   Each of you has received the agenda. I will e...
# 1       Commissioner Brown                                          So moved.
# 2       Commissioner Hobbs                                           Seconded
# 3        Chairman Wormsley   It has been moved and seconded that the agend...
# 4   Commissioner McCroskey   Mister Chairman, my name has been omitted fro...
# 5        Chairman Wormsley   Thank you. If there are no objections, the mi...
# 6        Chairman Wormsley   Commissioner Adkins, the first item on the ag...
# 7      Commissioner Adkins   Mister Chairman, I would like to make a motio...
# 8    Commissioner Carmical                               I second the motion.
# 9        Chairman Wormsley   This resolution has a motion and second. Will...
# 10       Chairman Wormsley   The resolution passes. We will now take up ol...
# 11      Commissioner McKee                    I move to withdraw that motion.
# 12       Chairman Wormsley   Commissioner McKee has moved to withdraw his ...
# 13    Commissioner Rodgers   I move adopton of the resolution previously p...
# 14       Chairman Wormsley                               Commissioner Duckett
# 15    Commissioner Duckett           The sheriff is opposed to this increase.
# 16       Chairman Wormsley   Commissioner, you are out of order because th...
# 17   Commissioner Reinhart   For purposes of discussion, I second the motion.
# 18       Chairman Wormsley                Commissioner Rodgers is recognized.
# 19    Commissioner Rodgers   (Speaks about the data on collections, handin...
# 20       Chairman Wormsley                               Commissioner Duckett
# 21    Commissioner Duckett   I move an amendment to the motion to require ...
# 22       Chairman Wormsley                                Commissioner Malone
# 23     Commissioner Malone                            I second the amendment.
# 24       Chairman Wormsley   A motion has been made and seconded to amend ...
# 25   Commissioner Headrick               Does this require a two-thirds vote?
# 26       Chairman Wormsley     Will the county attorney answer that question?
# 27   County Attorney Fults   Since these are only courts of record, a majo...
# 28       Chairman Wormsley   Other questions or discussion? Commissioner A...
# 29      Commissioner Adams                         Move for a roll call vote.
# 30   Commissioner Crenshaw                                             Second
# 31       Chairman Wormsley   The motion has been made and seconded that th...
# 32     Commissioner Adkins   Each of you has previously received a copy of...
# 33       Chairman Wormsley                              Commissioner Thompson
# 34   Commissioner Thompson                                          I second.
# 35       Chairman Wormsley   It has been properly moved and seconded that ...
# 36      Commissioner Hayes                          I move previous question.
# 37    Commisioner Crenshaw                                            Second.
# 38       Chairman Wormsley   Previous question has been moved and seconded...
# 39     Commissioner Hailey   There will be a meeting of the Budget Committ...
# 40       Chairman Wormsley   Any other announcements? The next meeting of ...
# 41   Commissioner Carmical   There will be a chili supper at County Elemen...
# 42       Chairman Wormsley                               Commissioner Austin.
# 43     Commissioner Austin                                  Move adjournment.
# 44    Commissioner Garland                                            Second.
# 45       Chairman Wormsley   Without objection, the meeting will stand adj...

# %%
train2 = asr_output['role'].str.split(" ", expand = True) 
train2.head(5)
# Out:
#               0          1     2
# 0      Chairman   Wormsley  None
# 1  Commissioner      Brown  None
# 2  Commissioner      Hobbs  None
# 3      Chairman   Wormsley  None
# 4  Commissioner  McCroskey  None

# %%
asr_output['role']=train2[1]

# %%
asr_output.head()
# Out:
#         role                                                utt
# 0   Wormsley   Each of you has received the agenda. I will e...
# 1      Brown                                          So moved.
# 2      Hobbs                                           Seconded
# 3   Wormsley   It has been moved and seconded that the agend...
# 4  McCroskey   Mister Chairman, my name has been omitted fro...

# %%
labels=list(asr_output['utt'])  # done

# %%
path_to_stopwords    = '/content/gdrive/My Drive/summerization/Create_DATA/CoreRank/resources/stopwords/meeting/stopwords.en.dat'
path_to_filler_words = '/content/gdrive/My Drive/summerization/Create_DATA/CoreRank/resources/stopwords/meeting/filler_words.en.txt'
stopwords = load_stopwords(path_to_stopwords) #not used
filler_words = load_filler_words(path_to_filler_words)

# %%
utterances = []
for tmp in zip(asr_output['role'].tolist(), asr_output['utt'].tolist()):
  role, utt = tmp
  for ch in ['{vocalsound}', '{gap}', '{disfmarker}', '{comment}', '{pause}', '@reject@']:
    utt = re.sub(ch, '', utt) # cleaning
    utt = re.sub("'Kay", 'Okay', utt)
    utt = re.sub("'kay", 'Okay', utt)
    utt = re.sub('"Okay"', 'Okay', utt)
    utt = re.sub("'cause", 'cause', utt)
    utt = re.sub("'Cause", 'cause', utt)
    utt = re.sub('"cause"', 'cause', utt)
    utt = re.sub('"\'em"', 'them', utt)
    utt = re.sub('"\'til"', 'until', utt)
    utt = re.sub('"\'s"', 's', utt)

        # l. c. d. -> lcd
        # t. v. -> tv
    utt = re.sub('h. t. m. l.', 'html', utt)
    utt = re.sub(r"(\w)\. (\w)\. (\w)\.", r"\1\2\3", utt)
    utt = re.sub(r"(\w)\. (\w)\.", r"\1\2", utt)
    utt = re.sub(r"(\w)\.", r"\1", utt)

        # clean_utterance, remove filler_words
    utt = clean_utterance(utt, filler_words=filler_words)

        # strip extra white space
    utt = re.sub(' +', ' ', utt)
        # strip leading and trailing white space
    utt = utt.strip()

    if utt != '' and utt != '.' and utt != ' ':
      utterances.append((role, utt))

    # remove duplicate utterances per speaker
    utterances = sorted(set(utterances), key=utterances.index)
    utterances_indexed = zip(range(len(utterances)), zip(*utterances)[0], zip(*utterances)[1])

# %%
fil=[]
for i in utterances:
  fil.append(i[1])

# %%
fil
# Out:
# ['Each of you has received the agenda I will entertain a motion that the agenda be approved',
#  'So moved',
#  'Seconded',
#  'It has been moved and seconded that the agenda be approved as received by the members All those in favor signify by saying "Aye"?...Opposed by saying "No"?...The agenda is approved You have received a copy of the minutes of the last meeting Are there any corrections or additions to the meeting?',
#  'Mister Chairman, my name has been omitted from the Special Committee on Indigent Care',
#  'If there are no objections, the minutes will be corrected to include the name of Commissioner McCroskey Will the clerk make this correction Any further corrections? Seeing none, without objection the minutes will stand approved as read (This is a short cut way that is commonly used for approval of minutes and/or the agenda rather than requiring a motion and second)',
#  'Commissioner Adkins, the first item on the agenda is yours',
#  "Mister Chairman, I would like to make a motion to approve the resolution taking money from the Data Processing Reserve Account in the County Clerk's office and moving it to the equipment line to purchase a laptop computer",
#  'I second the motion',
#  'This resolution has a motion and second Will the clerk take the vote',
#  'The resolution passes We will now take up old business At our last meeting, Commissioner McKee, your motion to sell property near the airport was deferred to this meeting You are recognized',
#  'I move to withdraw that motion',
#  "Commissioner McKee has moved to withdraw his motion to sell property near the airport Seeing no objection, this motion is withdrawn The next item on the agenda is Commissioner Rodgers'.",
#  'I move adopton of the resolution previously provided to each of you to increase the state match local litigation tax in circuit, chancery, and criminal courts to the maximum amounts permissible This resolution calls for the increases to go to the general fund',
#  'Commissioner Duckett',
#  'The sheriff is opposed to this increase',
#  'Commissioner, you are out of order because this motion has not been seconded as needed before the floor is open for discussion or debate Discussion will begin after we have a second Is there a second?',
#  'For purposes of discussion, I second the motion',
#  'Commissioner Rodgers is recognized',
#  "(Speaks about the data on collections, handing out all sorts of numerical figures regarding the litigation tax, and the county's need for additional revenue)",
#  "I move an amendment to the motion to require 25 percent of the proceeds from the increase in the tax on criminal cases go to fund the sheriff's department",
#  'Commissioner Malone',
#  'I second the amendment',
#  "A motion has been made and seconded to amend the motion to increase the state match local litigation taxes to the maximum amounts to require 25 percent of the proceeds from the increase in the tax on criminal cases in courts of record going to fund the sheriff's department Any discussion? Will all those in favor raise your hand? All those opposed raise your hand The amendment carries 17-2 We are now on the motion as amended Any further discussion?",
#  'Does this require a two-thirds vote?',
#  'Will the county attorney answer that question?',
#  'Since these are only courts of record, a majority vote will pass it The two-thirds requirement is for the general sessions taxes',
#  'Other questions or discussion? Commissioner Adams',
#  'Move for a roll call vote',
#  'Second',
#  'The motion has been made and seconded that the state match local litigation taxes be increased to the maximum amounts allowed by law with 25 percent of the proceeds from the increase in the tax on criminal cases in courts of record going to fund the sheriff\'s department Will all those in favor vote as the clerk calls your name, those in favor vote "aye," those against vote "no" Nine votes for, nine votes against, one not voting The increase fails We are now on new business Commissioner Adkins, the first item on the agenda is yours',
#  'Each of you has previously received a copy of a resolution to increase the wheel tax by $10 to make up the state cut in education funding I move adoption of this resolution',
#  'Commissioner Thompson',
#  'I second',
#  'It has been properly moved and seconded that a resolution increasing the wheel tax by $10 to make up the state cut in education funding be passed Any discussion? (At this point numerous county commissioners speak for and against increasing the wheel tax and making up the education cuts This is the first time this resolution is under consideration) Commissioner Hayes is recognized',
#  'I move previous question',
#  'Previous question has been moved and seconded As you know, a motion for previous question, if passed by a two-thirds vote, will cut off further debate and require us to vote yes or no on the resolution before us You should vote for this motion if you wish to cut off further debate of the wheel tax increase at this point Will all those in favor of previous question raise your hand? Will all those against raise your hand? The vote is 17-2 Previous question passes We are now on the motion to increase the wheel tax by $10 to make up the state cut in education funding Will all those in favor raise your hand? Will all those against raise your hand? The vote is 17-2 This increase passes on first passage Is there any other new business? Since no member is seeking recognition, are there announcements? Commissioner Hailey',
#  'There will be a meeting of the Budget Committee to look at solid waste funding recommendations on Tuesday, July 16 at noon here in this room',
#  'Any other announcements? The next meeting of this body will be Monday, August 19 at 7 pm, here in this room Commissioner Carmical',
#  'There will be a chili supper at County Elementary School on August 16 at 6',
#  'Commissioner Austin',
#  'Move adjournment',
#  'Second',
#  'Without objection, the meeting will stand adjourned']

# %%
# #############################
# ### CORPUS PRE-PROCESSING ###
# #############################
from nltk import PerceptronTagger
tagger = PerceptronTagger()

final=[]   
for i in utterances_indexed:
  index, role, utt = i
  tokens = utt.split(' ')
  tokens_tagged = [tuple[0] + '/' + (tuple[1] if tuple[0] not in string.punctuation else 'PUNCT') for tuple in tagger.tag(tokens)]
  final.append((index, role,' '.join(tokens_tagged)))
  #if index==2:
   # break

# %%
texts=final
texts
# Out:
# [(0,
#   'Wormsley',
#   'Each/DT of/IN you/PRP has/VBZ received/VBN the/DT agenda/NN I/PRP will/MD entertain/VB a/DT motion/NN that/IN the/DT agenda/NN be/VB approved/VBN'),
#  (1, 'Brown', 'So/RB moved/VBD'),
#  (2, 'Hobbs', 'Seconded/VBN'),
#  (3,
#   'Wormsley',
#   'It/PRP has/VBZ been/VBN moved/VBN and/CC seconded/VBD that/IN the/DT agenda/NN be/VB approved/VBN as/IN received/VBN by/IN the/DT members/NNS All/VBP those/DT in/IN favor/NN signify/NN by/IN saying/VBG "Aye"?...Opposed/VBN by/IN saying/VBG "No"?...The/JJ agenda/NN is/VBZ approved/VBN You/PRP have/VBP received/VBN a/DT copy/NN of/IN the/DT minutes/NNS of/IN the/DT last/JJ meeting/NN Are/NNP there/RB any/DT corrections/NNS or/CC additions/NNS to/TO the/DT meeting?/NN'),
#  (4,
#   'McCroskey',
#   'Mister/NNP Chairman,/NNP my/PRP$ name/NN has/VBZ been/VBN omitted/VBN from/IN the/DT Special/NNP Committee/NNP on/IN Indigent/NNP Care/NNP'),
#  (5,
#   'Wormsley',
#   'If/IN there/EX are/VBP no/DT objections,/IN the/DT minutes/NNS will/MD be/VB corrected/VBN to/TO include/VB the/DT name/NN of/IN Commissioner/NNP McCroskey/NNP Will/NNP the/DT clerk/NN make/VBP this/DT correction/NN Any/NNP further/RB corrections?/VBD Seeing/VBG none,/NN without/IN objection/NN the/DT minutes/NNS will/MD stand/VB approved/VBN as/IN read/NN (This/NN is/VBZ a/DT short/JJ cut/NN way/NN that/WDT is/VBZ commonly/RB used/VBN for/IN approval/NN of/IN minutes/NNS and/or/VBP the/DT agenda/NN rather/RB than/IN requiring/VBG a/DT motion/NN and/CC second)/NN'),
#  (6,
#   'Wormsley',
#   'Commissioner/NNP Adkins,/NNP the/DT first/JJ item/NN on/IN the/DT agenda/NN is/VBZ yours/NNS'),
#  (7,
#   'Adkins',
#   "Mister/NNP Chairman,/NNP I/PRP would/MD like/VB to/TO make/VB a/DT motion/NN to/TO approve/VB the/DT resolution/NN taking/VBG money/NN from/IN the/DT Data/NNP Processing/NNP Reserve/NNP Account/NNP in/IN the/DT County/NNP Clerk's/NNP office/NN and/CC moving/VBG it/PRP to/TO the/DT equipment/NN line/NN to/TO purchase/VB a/DT laptop/JJ computer/NN"),
#  (8, 'Carmical', 'I/PRP second/VBP the/DT motion/NN'),
#  (9,
#   'Wormsley',
#   'This/DT resolution/NN has/VBZ a/DT motion/NN and/CC second/NN Will/NNP the/DT clerk/NNS take/VBP the/DT vote/NN'),
#  (10,
#   'Wormsley',
#   'The/DT resolution/NN passes/VBZ We/PRP will/MD now/RB take/VB up/RP old/JJ business/NN At/IN our/PRP$ last/JJ meeting,/NN Commissioner/NNP McKee,/NNP your/PRP$ motion/NN to/TO sell/VB property/NN near/IN the/DT airport/NN was/VBD deferred/VBN to/TO this/DT meeting/NN You/PRP are/VBP recognized/VBN'),
#  (11, 'McKee', 'I/PRP move/VBP to/TO withdraw/VB that/DT motion/NN'),
#  (12,
#   'Wormsley',
#   "Commissioner/NNP McKee/NNP has/VBZ moved/VBN to/TO withdraw/VB his/PRP$ motion/NN to/TO sell/VB property/NN near/IN the/DT airport/NN Seeing/VBG no/DT objection,/NN this/DT motion/NN is/VBZ withdrawn/VBN The/DT next/JJ item/NN on/IN the/DT agenda/NN is/VBZ Commissioner/NNP Rodgers'./NNP"),
#  (13,
#   'Rodgers',
#   'I/PRP move/VBP adopton/NN of/IN the/DT resolution/NN previously/RB provided/VBN to/TO each/DT of/IN you/PRP to/TO increase/VB the/DT state/NN match/NN local/JJ litigation/NN tax/NN in/IN circuit,/NN chancery,/NN and/CC criminal/JJ courts/NNS to/TO the/DT maximum/JJ amounts/NNS permissible/JJ This/DT resolution/NN calls/VBZ for/IN the/DT increases/NNS to/TO go/VB to/TO the/DT general/JJ fund/NN'),
#  (14, 'Wormsley', 'Commissioner/NNP Duckett/NNP'),
#  (15,
#   'Duckett',
#   'The/DT sheriff/NN is/VBZ opposed/VBN to/TO this/DT increase/NN'),
#  (16,
#   'Wormsley',
#   'Commissioner,/NNP you/PRP are/VBP out/IN of/IN order/NN because/IN this/DT motion/NN has/VBZ not/RB been/VBN seconded/VBN as/IN needed/VBN before/IN the/DT floor/NN is/VBZ open/JJ for/IN discussion/NN or/CC debate/NN Discussion/NNP will/MD begin/VB after/IN we/PRP have/VBP a/DT second/JJ Is/NNP there/EX a/DT second?/NN'),
#  (17,
#   'Reinhart',
#   'For/IN purposes/NNS of/IN discussion,/NN I/PRP second/VBP the/DT motion/NN'),
#  (18, 'Wormsley', 'Commissioner/NNP Rodgers/NNP is/VBZ recognized/VBN'),
#  (19,
#   'Rodgers',
#   "(Speaks/NNS about/IN the/DT data/NNS on/IN collections,/NN handing/VBG out/RP all/DT sorts/NNS of/IN numerical/JJ figures/NNS regarding/VBG the/DT litigation/NN tax,/NN and/CC the/DT county's/NNS need/VBP for/IN additional/JJ revenue)/NN"),
#  (20,
#   'Duckett',
#   "I/PRP move/VBP an/DT amendment/NN to/TO the/DT motion/NN to/TO require/VB 25/CD percent/NN of/IN the/DT proceeds/NNS from/IN the/DT increase/NN in/IN the/DT tax/NN on/IN criminal/JJ cases/NNS go/VBP to/TO fund/VB the/DT sheriff's/NN department/NN"),
#  (21, 'Wormsley', 'Commissioner/NNP Malone/NNP'),
#  (22, 'Malone', 'I/PRP second/VBP the/DT amendment/NN'),
#  (23,
#   'Wormsley',
#   "A/DT motion/NN has/VBZ been/VBN made/VBN and/CC seconded/VBN to/TO amend/VB the/DT motion/NN to/TO increase/VB the/DT state/NN match/NN local/JJ litigation/NN taxes/NNS to/TO the/DT maximum/JJ amounts/NNS to/TO require/VB 25/CD percent/NN of/IN the/DT proceeds/NNS from/IN the/DT increase/NN in/IN the/DT tax/NN on/IN criminal/JJ cases/NNS in/IN courts/NNS of/IN record/NN going/VBG to/TO fund/VB the/DT sheriff's/JJ department/NN Any/NNP discussion?/NN Will/NNP all/DT those/DT in/IN favor/NN raise/VB your/PRP$ hand?/NN All/PDT those/DT opposed/VBN raise/VB your/PRP$ hand/NN The/DT amendment/NN carries/VBZ 17-2/CD We/PRP are/VBP now/RB on/IN the/DT motion/NN as/IN amended/VBN Any/NNP further/JJ discussion?/NN"),
#  (24, 'Headrick', 'Does/VBZ this/DT require/VB a/DT two-thirds/NNS vote?/NN'),
#  (25,
#   'Wormsley',
#   'Will/MD the/DT county/NN attorney/NN answer/NN that/IN question?/NN'),
#  (26,
#   'Attorney',
#   'Since/IN these/DT are/VBP only/RB courts/NNS of/IN record,/NN a/DT majority/NN vote/NN will/MD pass/VB it/PRP The/DT two-thirds/JJ requirement/NN is/VBZ for/IN the/DT general/JJ sessions/NNS taxes/NNS'),
#  (27,
#   'Wormsley',
#   'Other/JJ questions/NNS or/CC discussion?/JJ Commissioner/NNP Adams/NNP'),
#  (28, 'Adams', 'Move/NNP for/IN a/DT roll/NN call/NN vote/NN'),
#  (29, 'Crenshaw', 'Second/JJ'),
#  (30,
#   'Wormsley',
#   'The/DT motion/NN has/VBZ been/VBN made/VBN and/CC seconded/VBD that/IN the/DT state/NN match/NN local/JJ litigation/NN taxes/NNS be/VB increased/VBN to/TO the/DT maximum/JJ amounts/NNS allowed/VBN by/IN law/NN with/IN 25/CD percent/NN of/IN the/DT proceeds/NNS from/IN the/DT increase/NN in/IN the/DT tax/NN on/IN criminal/JJ cases/NNS in/IN courts/NNS of/IN record/NN going/VBG to/TO fund/VB the/DT sheriff\'s/NN department/NN Will/NNP all/PDT those/DT in/IN favor/JJ vote/NN as/IN the/DT clerk/NN calls/VBZ your/PRP$ name,/NNS those/DT in/IN favor/JJ vote/NN "aye,"/VBD those/DT against/IN vote/NN "no"/JJ Nine/NNP votes/VBZ for,/JJ nine/CD votes/NNS against,/VBP one/CD not/RB voting/VBG The/DT increase/NN fails/VBZ We/PRP are/VBP now/RB on/IN new/JJ business/NN Commissioner/NNP Adkins,/NNP the/DT first/JJ item/NN on/IN the/DT agenda/NN is/VBZ yours/NNS'),
#  (31,
#   'Adkins',
#   'Each/DT of/IN you/PRP has/VBZ previously/RB received/VBN a/DT copy/NN of/IN a/DT resolution/NN to/TO increase/VB the/DT wheel/NN tax/NN by/IN $10/NN to/TO make/VB up/RP the/DT state/NN cut/NN in/IN education/NN funding/NN I/PRP move/VBP adoption/NN of/IN this/DT resolution/NN'),
#  (32, 'Wormsley', 'Commissioner/NNP Thompson/NNP'),
#  (33, 'Thompson', 'I/PRP second/VBP'),
#  (34,
#   'Wormsley',
#   'It/PRP has/VBZ been/VBN properly/RB moved/VBN and/CC seconded/VBD that/IN a/DT resolution/NN increasing/VBG the/DT wheel/NN tax/NN by/IN $10/NN to/TO make/VB up/RP the/DT state/NN cut/NN in/IN education/NN funding/NN be/VB passed/VBN Any/NNP discussion?/JJ (At/NN this/DT point/NN numerous/JJ county/NN commissioners/NNS speak/VBP for/IN and/CC against/IN increasing/VBG the/DT wheel/NN tax/NN and/CC making/VBG up/RP the/DT education/NN cuts/NNS This/DT is/VBZ the/DT first/JJ time/NN this/DT resolution/NN is/VBZ under/IN consideration)/NN Commissioner/NNP Hayes/NNP is/VBZ recognized/VBN'),
#  (35, 'Hayes', 'I/PRP move/VBP previous/JJ question/NN'),
#  (36,
#   'Wormsley',
#   'Previous/JJ question/NN has/VBZ been/VBN moved/VBN and/CC seconded/VBN As/IN you/PRP know,/VBP a/DT motion/NN for/IN previous/JJ question,/NN if/IN passed/VBN by/IN a/DT two-thirds/JJ vote,/NN will/MD cut/VB off/RP further/JJ debate/NN and/CC require/VB us/PRP to/TO vote/VB yes/NNS or/CC no/DT on/IN the/DT resolution/NN before/IN us/PRP You/PRP should/MD vote/VB for/IN this/DT motion/NN if/IN you/PRP wish/VBP to/TO cut/VB off/RP further/JJ debate/NN of/IN the/DT wheel/NN tax/NN increase/NN at/IN this/DT point/NN Will/NNP all/PDT those/DT in/IN favor/NN of/IN previous/JJ question/NN raise/VB your/PRP$ hand?/NN Will/NNP all/PDT those/DT against/IN raise/VB your/PRP$ hand?/PDT The/DT vote/NN is/VBZ 17-2/JJ Previous/JJ question/NN passes/VBZ We/PRP are/VBP now/RB on/IN the/DT motion/NN to/TO increase/VB the/DT wheel/NN tax/NN by/IN $10/NN to/TO make/VB up/RP the/DT state/NN cut/NN in/IN education/NN funding/NN Will/NNP all/DT those/DT in/IN favor/NN raise/VB your/PRP$ hand?/NN Will/NNP all/PDT those/DT against/IN raise/VB your/PRP$ hand?/PDT The/DT vote/NN is/VBZ 17-2/JJ This/DT increase/NN passes/VBZ on/IN first/JJ passage/NN Is/VBZ there/RB any/DT other/JJ new/JJ business?/NNS Since/IN no/DT member/NN is/VBZ seeking/VBG recognition,/NN are/VBP there/RB announcements?/JJ Commissioner/NNP Hailey/NNP'),
#  (37,
#   'Hailey',
#   'There/EX will/MD be/VB a/DT meeting/NN of/IN the/DT Budget/NNP Committee/NNP to/TO look/VB at/IN solid/JJ waste/NN funding/NN recommendations/NNS on/IN Tuesday,/NNP July/NNP 16/CD at/IN noon/NN here/RB in/IN this/DT room/NN'),
#  (38,
#   'Wormsley',
#   'Any/DT other/JJ announcements?/IN The/DT next/JJ meeting/NN of/IN this/DT body/NN will/MD be/VB Monday,/NNP August/NNP 19/CD at/IN 7/CD pm,/NN here/RB in/IN this/DT room/NN Commissioner/NNP Carmical/NNP'),
#  (39,
#   'Carmical',
#   'There/EX will/MD be/VB a/DT chili/JJ supper/NN at/IN County/NNP Elementary/NNP School/NNP on/IN August/NNP 16/CD at/IN 6/CD'),
#  (40, 'Wormsley', 'Commissioner/NNP Austin/NNP'),
#  (41, 'Austin', 'Move/NNP adjournment/NN'),
#  (42, 'Garland', 'Second/JJ'),
#  (43,
#   'Wormsley',
#   'Without/IN objection,/PDT the/DT meeting/NN will/MD stand/VB adjourned/VBD')]

# %%
'''
texts = Text
labels = str(labels)
word_pos=None
dialogues = []
data_list = []
for each in texts:
  role = each[1]
  sentence = ' '.join(word_pos.split('/')[0] for word_pos in each[2].split())
  sentence = sentence.strip().lower()
  pos_sentence = ' '.join(word_pos.split('/')[1] for word_pos in each[2].split())
  pos_sentence = pos_sentence.strip().lower()
  dialogues.append({'role': role, 'sentence': sentence, 'pos_sentence': pos_sentence})
data_list.append({'labels': labels, 'dialogues': dialogues})
'''
# Out:
# "\ntexts = Text\nlabels = str(labels)\nword_pos=None\ndialogues = []\ndata_list = []\nfor each in texts:\n  role = each[1]\n  sentence = ' '.join(word_pos.split('/')[0] for word_pos in each[2].split())\n  sentence = sentence.strip().lower()\n  pos_sentence = ' '.join(word_pos.split('/')[1] for word_pos in each[2].split())\n  pos_sentence = pos_sentence.strip().lower()\n  dialogues.append({'role': role, 'sentence': sentence, 'pos_sentence': pos_sentence})\ndata_list.append({'labels': labels, 'dialogues': dialogues})\n"

# %%
'''
with open("testing.txt", "w") as file:
    file.write(str(data_list))

with open("testing.txt", "r") as file:
    data2 = eval(file.readline())
'''
# Out:
# '\nwith open("testing.txt", "w") as file:\n    file.write(str(data_list))\n\nwith open("testing.txt", "r") as file:\n    data2 = eval(file.readline())\n'

# %%
labels=fil

# %%
print(len(labels))
print(len(texts))
# Out:
# 44
# 44

# %%
l1=[]
for i in labels:
  if i != '{vocalsound}':
    l1.append(i + ' ||')

# %%
l1[43]
# Out:
# 'Without objection, the meeting will stand adjourned ||'

# %%
l1[43]='Without objection, the meeting will stand adjourned'

# %%
l1
# Out:
# ['Each of you has received the agenda I will entertain a motion that the agenda be approved ||',
#  'So moved ||',
#  'Seconded ||',
#  'It has been moved and seconded that the agenda be approved as received by the members All those in favor signify by saying "Aye"?...Opposed by saying "No"?...The agenda is approved You have received a copy of the minutes of the last meeting Are there any corrections or additions to the meeting? ||',
#  'Mister Chairman, my name has been omitted from the Special Committee on Indigent Care ||',
#  'If there are no objections, the minutes will be corrected to include the name of Commissioner McCroskey Will the clerk make this correction Any further corrections? Seeing none, without objection the minutes will stand approved as read (This is a short cut way that is commonly used for approval of minutes and/or the agenda rather than requiring a motion and second) ||',
#  'Commissioner Adkins, the first item on the agenda is yours ||',
#  "Mister Chairman, I would like to make a motion to approve the resolution taking money from the Data Processing Reserve Account in the County Clerk's office and moving it to the equipment line to purchase a laptop computer ||",
#  'I second the motion ||',
#  'This resolution has a motion and second Will the clerk take the vote ||',
#  'The resolution passes We will now take up old business At our last meeting, Commissioner McKee, your motion to sell property near the airport was deferred to this meeting You are recognized ||',
#  'I move to withdraw that motion ||',
#  "Commissioner McKee has moved to withdraw his motion to sell property near the airport Seeing no objection, this motion is withdrawn The next item on the agenda is Commissioner Rodgers'. ||",
#  'I move adopton of the resolution previously provided to each of you to increase the state match local litigation tax in circuit, chancery, and criminal courts to the maximum amounts permissible This resolution calls for the increases to go to the general fund ||',
#  'Commissioner Duckett ||',
#  'The sheriff is opposed to this increase ||',
#  'Commissioner, you are out of order because this motion has not been seconded as needed before the floor is open for discussion or debate Discussion will begin after we have a second Is there a second? ||',
#  'For purposes of discussion, I second the motion ||',
#  'Commissioner Rodgers is recognized ||',
#  "(Speaks about the data on collections, handing out all sorts of numerical figures regarding the litigation tax, and the county's need for additional revenue) ||",
#  "I move an amendment to the motion to require 25 percent of the proceeds from the increase in the tax on criminal cases go to fund the sheriff's department ||",
#  'Commissioner Malone ||',
#  'I second the amendment ||',
#  "A motion has been made and seconded to amend the motion to increase the state match local litigation taxes to the maximum amounts to require 25 percent of the proceeds from the increase in the tax on criminal cases in courts of record going to fund the sheriff's department Any discussion? Will all those in favor raise your hand? All those opposed raise your hand The amendment carries 17-2 We are now on the motion as amended Any further discussion? ||",
#  'Does this require a two-thirds vote? ||',
#  'Will the county attorney answer that question? ||',
#  'Since these are only courts of record, a majority vote will pass it The two-thirds requirement is for the general sessions taxes ||',
#  'Other questions or discussion? Commissioner Adams ||',
#  'Move for a roll call vote ||',
#  'Second ||',
#  'The motion has been made and seconded that the state match local litigation taxes be increased to the maximum amounts allowed by law with 25 percent of the proceeds from the increase in the tax on criminal cases in courts of record going to fund the sheriff\'s department Will all those in favor vote as the clerk calls your name, those in favor vote "aye," those against vote "no" Nine votes for, nine votes against, one not voting The increase fails We are now on new business Commissioner Adkins, the first item on the agenda is yours ||',
#  'Each of you has previously received a copy of a resolution to increase the wheel tax by $10 to make up the state cut in education funding I move adoption of this resolution ||',
#  'Commissioner Thompson ||',
#  'I second ||',
#  'It has been properly moved and seconded that a resolution increasing the wheel tax by $10 to make up the state cut in education funding be passed Any discussion? (At this point numerous county commissioners speak for and against increasing the wheel tax and making up the education cuts This is the first time this resolution is under consideration) Commissioner Hayes is recognized ||',
#  'I move previous question ||',
#  'Previous question has been moved and seconded As you know, a motion for previous question, if passed by a two-thirds vote, will cut off further debate and require us to vote yes or no on the resolution before us You should vote for this motion if you wish to cut off further debate of the wheel tax increase at this point Will all those in favor of previous question raise your hand? Will all those against raise your hand? The vote is 17-2 Previous question passes We are now on the motion to increase the wheel tax by $10 to make up the state cut in education funding Will all those in favor raise your hand? Will all those against raise your hand? The vote is 17-2 This increase passes on first passage Is there any other new business? Since no member is seeking recognition, are there announcements? Commissioner Hailey ||',
#  'There will be a meeting of the Budget Committee to look at solid waste funding recommendations on Tuesday, July 16 at noon here in this room ||',
#  'Any other announcements? The next meeting of this body will be Monday, August 19 at 7 pm, here in this room Commissioner Carmical ||',
#  'There will be a chili supper at County Elementary School on August 16 at 6 ||',
#  'Commissioner Austin ||',
#  'Move adjournment ||',
#  'Second ||',
#  'Without objection, the meeting will stand adjourned']

# %%
l2 = ' '.join([elem for elem in l1])

# %%
replaced_string=l2

# %%
with open("original_reference.txt", "w") as output:
  output.write(str(replaced_string))

# %%
A=dict(texts=texts,labels=replaced_string)

# %%
for key,value in A.items():
  print(key)
# Out:
# texts
# labels

# %%
import torch
torch.save({
            'ES2004a': A
            }, 'corrected_corpus')

# %%
new=torch.load('corrected_corpus')

# %%
for key, value in new.items():
  print(key)
  #texts = value['texts']
  #labels = value['labels']
  #tok=key
# Out:
# ES2004a
